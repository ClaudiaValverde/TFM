# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tqdm import tqdm  # For progress tracking
import pandas as pd
import requests
import os

import time
from tqdm import tqdm
from collections import defaultdict, Counter

# plots
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def extract_families(uniprot_ids):
  """
    Retrieve and extract protein family annotations from the UniProt database for a list of UniProt IDs.

    This function queries the UniProt REST API for each provided UniProt ID, extracts associated
    Pfam and InterPro family identifiers, and counts the frequency of these families across all proteins.
    For each protein, the most frequent Pfam family (if any) is recorded.

    Args:
        uniprot_ids (list of str): A list of UniProt protein accession IDs to query.

    Returns:
        pd.DataFrame: A DataFrame with columns ["Protein_ID", "Pfam_Families"], mapping each protein ID
                      to its most frequently occurring Pfam family (if found).

    Notes:
        - The function introduces a small delay (0.1s) between requests to avoid API rate limits.
        - Requires 'requests', 'pandas', 'tqdm' libraries.
  """
  # UniProt API endpoint
  base_url = "https://rest.uniprot.org/uniprotkb/"

  # Dictionaries to store family counts
  pfam_counts = Counter()
  interpro_counts = Counter()
  protein_to_pfam = defaultdict(list)

  # Query UniProt API
  for index, protein_id in tqdm(enumerate(uniprot_ids), desc='Extracting Families...', total=len(uniprot_ids)):
      response = requests.get(f"{base_url}{protein_id}.json")

      if response.status_code == 200:
          data = response.json()

          # Extract Pfam & InterPro families
          pfam_list = []
          interpro_list = []

          for entry in data.get("uniProtKBCrossReferences", []):
              db, family_id = entry["database"], entry["id"]
              if db == "Pfam":
                  pfam_list.append(family_id)
              elif db == "InterPro":
                  interpro_list.append(family_id)

          # Choose the most frequent family per protein (if any exist)
          if pfam_list:
              most_common_pfam = Counter(pfam_list).most_common(1)[0][0]
              pfam_counts[most_common_pfam] += 1
              protein_to_pfam[protein_id] = most_common_pfam

          if interpro_list:
              most_common_interpro = Counter(interpro_list).most_common(1)[0][0]
              interpro_counts[most_common_interpro] += 1

      else:
          print(f"Failed to retrieve data for {protein_id}")

      # Print progress every 100 proteins
      if (index + 1) % 100 == 0:
          print(f"Processed {index + 1} proteins...")


      # Delay to avoid API rate limits
      time.sleep(0.1)

  # Sorting families by frequency (descending)
  sorted_pfam = sorted(pfam_counts.items(), key=lambda x: x[1], reverse=True)
  sorted_interpro = sorted(interpro_counts.items(), key=lambda x: x[1], reverse=True)

  df_pfam = pd.DataFrame(protein_to_pfam.items(), columns=["Protein_ID", "Pfam_Families"])
  return df_pfam

# %%
# loading Plinder Data (train+valid+test split)

plinder = pd.read_csv('/content/drive/MyDrive/Binder_Generation/protein_pocket_analysis/plinder_pocket_data_only1_ligands.csv')
plinder
# Out:
#        pdb_id                       ligand_id  Label  split  \
# 0        1grx          1grx__1__1.A__1.B__1.B      1  train
# 1        3grj          3grj__1__1.A__1.H__1.H      1  train
# 2        2grt      2grt__1__1.A_2.A__1.C__1.C      1  train
# 3        2grt      2grt__1__1.A_2.A__2.C__1.C      1  train
# 4        6grq          6grq__1__1.A__1.B__1.B      1  train
# ...       ...                             ...    ...    ...
# 128842   5ib9  5ib9__1__1.A__1.B_1.C_1.H__1.H      1   test
# 128843   5ib9  5ib9__1__2.A__2.B_2.C_2.H__1.H      1   test
# 128844   4xpp          4xpp__1__2.A__2.B__1.B      1   test
# 128845   3ug6  3ug6__1__1.C_1.D__1.M_1.N__1.M      1   test
# 128846   2y8l          2y8l__1__1.C__1.E__1.E      1   test
#
#                        pocket_key  \
# 0               1grx__1__1.A__1.B
# 1               3grj__1__1.A__1.H
# 2           2grt__1__1.A_2.A__1.C
# 3           2grt__1__1.A_2.A__2.C
# 4               6grq__1__1.A__1.B
# ...                           ...
# 128842  5ib9__1__1.A__1.B_1.C_1.H
# 128843  5ib9__1__2.A__2.B_2.C_2.H
# 128844          4xpp__1__2.A__2.B
# 128845  3ug6__1__1.C_1.D__1.M_1.N
# 128846          2y8l__1__1.C__1.E
#
#                                            cleaned_smiles
# 0          N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(=O)O)C(=O)O
# 1                            O=C(O)C1=CNC(C2=CC=CC=C2)=N1
# 2       N[C@@H](CCC(=O)N[C@@H](CSSC[C@H](NC(=O)CC[C@H]...
# 3       N[C@@H](CCC(=O)N[C@@H](CSSC[C@H](NC(=O)CC[C@H]...
# 4       CC(=O)N[C@H]1[C@H](O[C@H]2[C@H](O)[C@@H](NC(C)...
# ...                                                   ...
# 128842  CC(C)C[C@H](NC(=O)[C@@H](O)[C@H](N)CC1=CC=CC=C...
# 128843  CC(C)C[C@H](NC(=O)[C@@H](O)[C@H](N)CC1=CC=CC=C...
# 128844         OC[C@H]1O[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O
# 128845  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@](=O)(O)O...
# 128846  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@](=O)(O)O...
#
# [128847 rows x 6 columns]

# %%
print(f"Plinder Total Dataset Size: {len(plinder)} \nValid Dataset Size: {len(plinder[plinder['split']=='val'])} \nTrain Dataset Size: {len(plinder[plinder['split']=='train'])} \nTrain + Valid Dataset Size: {len(plinder[plinder['split']=='train']) + len(plinder[plinder['split']=='val'])} \nTest Dataset Size {len(plinder[plinder['split']=='test'])}")
# Out:
# Plinder Total Dataset Size: 128847
# Valid Dataset Size: 7460
# Train Dataset Size: 116644
# Train + Valid Dataset Size: 124104
# Test Dataset Size 4743

# %% [markdown]
# ### Preprocessing
# - Drop duplicate pdb ids
# - Convert pdb_ids to uniprot ids

# %%
plinder = plinder.drop_duplicates(subset='pdb_id')
plinder['pdb_id'] = plinder['pdb_id'].str.upper()
plinder
# Out:
# /tmp/ipython-input-6-3549886971.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plinder['pdb_id'] = plinder['pdb_id'].str.upper()
#        pdb_id                       ligand_id  Label  split  \
# 0        1GRX          1grx__1__1.A__1.B__1.B      1  train
# 1        3GRJ          3grj__1__1.A__1.H__1.H      1  train
# 2        2GRT      2grt__1__1.A_2.A__1.C__1.C      1  train
# 4        6GRQ          6grq__1__1.A__1.B__1.B      1  train
# 6        6GRI  6gri__1__1.C_2.C__1.I_1.J__1.I      1  train
# ...       ...                             ...    ...    ...
# 128839   7RGF          7rgf__1__1.A__1.F__1.F      1   test
# 128841   3RGX          3rgx__1__1.A__1.G__1.G      1   test
# 128842   5IB9  5ib9__1__1.A__1.B_1.C_1.H__1.H      1   test
# 128844   4XPP          4xpp__1__2.A__2.B__1.B      1   test
# 128846   2Y8L          2y8l__1__1.C__1.E__1.E      1   test
#
#                        pocket_key  \
# 0               1grx__1__1.A__1.B
# 1               3grj__1__1.A__1.H
# 2           2grt__1__1.A_2.A__1.C
# 4               6grq__1__1.A__1.B
# 6       6gri__1__1.C_2.C__1.I_1.J
# ...                           ...
# 128839          7rgf__1__1.A__1.F
# 128841          3rgx__1__1.A__1.G
# 128842  5ib9__1__1.A__1.B_1.C_1.H
# 128844          4xpp__1__2.A__2.B
# 128846          2y8l__1__1.C__1.E
#
#                                            cleaned_smiles
# 0          N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(=O)O)C(=O)O
# 1                            O=C(O)C1=CNC(C2=CC=CC=C2)=N1
# 2       N[C@@H](CCC(=O)N[C@@H](CSSC[C@H](NC(=O)CC[C@H]...
# 4       CC(=O)N[C@H]1[C@H](O[C@H]2[C@H](O)[C@@H](NC(C)...
# 6       CC1=CC2=C(C=C1C)N(C[C@H](O)[C@H](O)[C@H](O)COP...
# ...                                                   ...
# 128839        OC[C@H]1O[C@H](O)[C@@H](O)[C@@H](O)[C@@H]1O
# 128841  CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O
# 128842  CC(C)C[C@H](NC(=O)[C@@H](O)[C@H](N)CC1=CC=CC=C...
# 128844         OC[C@H]1O[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O
# 128846  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@](=O)(O)O...
#
# [30849 rows x 6 columns]

# %%
pdb_uniprot = pd.read_csv('/content/drive/MyDrive/Binder_Generation/protein_pocket_analysis/pdb_to_uniprot.csv')
pdb_uniprot
# Out:
#       pdb_id uniprot_id
# 0       103M     P02185
# 1       107M     P02185
# 2       108M     P02185
# 3       11AS     P00963
# 4       11BG     P00669
# ...      ...        ...
# 78606   9ICS     P06746
# 78607   9ICT     P06746
# 78608   9NSE     P29473
# 78609   9RSA     P61823
# 78610   9RUB     P04718
#
# [78611 rows x 2 columns]

# %%
pdb_uniprot_unique = pdb_uniprot.drop_duplicates(subset='pdb_id')

# %%
# geting uniprot ids to plinder proteins

plinder_uniprot = pd.merge(plinder, pdb_uniprot_unique, on='pdb_id', how='left')
plinder_uniprot
# Out:
#       pdb_id                       ligand_id  Label  split  \
# 0       1GRX          1grx__1__1.A__1.B__1.B      1  train
# 1       3GRJ          3grj__1__1.A__1.H__1.H      1  train
# 2       2GRT      2grt__1__1.A_2.A__1.C__1.C      1  train
# 3       6GRQ          6grq__1__1.A__1.B__1.B      1  train
# 4       6GRI  6gri__1__1.C_2.C__1.I_1.J__1.I      1  train
# ...      ...                             ...    ...    ...
# 30844   7RGF          7rgf__1__1.A__1.F__1.F      1   test
# 30845   3RGX          3rgx__1__1.A__1.G__1.G      1   test
# 30846   5IB9  5ib9__1__1.A__1.B_1.C_1.H__1.H      1   test
# 30847   4XPP          4xpp__1__2.A__2.B__1.B      1   test
# 30848   2Y8L          2y8l__1__1.C__1.E__1.E      1   test
#
#                       pocket_key  \
# 0              1grx__1__1.A__1.B
# 1              3grj__1__1.A__1.H
# 2          2grt__1__1.A_2.A__1.C
# 3              6grq__1__1.A__1.B
# 4      6gri__1__1.C_2.C__1.I_1.J
# ...                          ...
# 30844          7rgf__1__1.A__1.F
# 30845          3rgx__1__1.A__1.G
# 30846  5ib9__1__1.A__1.B_1.C_1.H
# 30847          4xpp__1__2.A__2.B
# 30848          2y8l__1__1.C__1.E
#
#                                           cleaned_smiles  uniprot_id
# 0         N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(=O)O)C(=O)O      P68688
# 1                           O=C(O)C1=CNC(C2=CC=CC=C2)=N1      P00811
# 2      N[C@@H](CCC(=O)N[C@@H](CSSC[C@H](NC(=O)CC[C@H]...      P00390
# 3      CC(=O)N[C@H]1[C@H](O[C@H]2[C@H](O)[C@@H](NC(C)...      Q8K4V6
# 4      CC1=CC2=C(C=C1C)N(C[C@H](O)[C@H](O)[C@H](O)COP...      P23184
# ...                                                  ...         ...
# 30844        OC[C@H]1O[C@H](O)[C@@H](O)[C@@H](O)[C@@H]1O      Q91XX0
# 30845  CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O      O22476
# 30846  CC(C)C[C@H](NC(=O)[C@@H](O)[C@H](N)CC1=CC=CC=C...      A2V759
# 30847         OC[C@H]1O[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O  A0A0F7R6D6
# 30848  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@](=O)(O)O...      O43741
#
# [30849 rows x 7 columns]

# %%
plinder_uniprot.to_csv('/content/drive/MyDrive/Binder_Generation/protein_pocket_analysis/plinder_uniprot_uniques.csv')

# %% [markdown]
# ### extracting families (run in a cluster)

# %%
# This was executed in a cluster due to colab computational limitations
#plinder_families = extract_families(plinder_uniprot['uniprot_id'])
# Out:
# Extracting Families...:   0%|          | 30/30849 [00:18<4:46:40,  1.79it/s]
# Failed to retrieve data for nan
# Extracting Families...:   0%|          | 100/30849 [01:02<4:56:59,  1.73it/s]
# Processed 100 proteins...
# Extracting Families...:   1%|          | 167/30849 [01:44<4:56:13,  1.73it/s]
# Failed to retrieve data for nan
# Extracting Families...:   1%|          | 200/30849 [02:05<5:27:25,  1.56it/s]
# Processed 200 proteins...
# Extracting Families...:   1%|          | 228/30849 [02:21<4:47:28,  1.78it/s]
# Failed to retrieve data for nan
# Extracting Families...:   1%|          | 235/30849 [02:25<4:50:25,  1.76it/s]
# Failed to retrieve data for nan
# Extracting Families...:   1%|          | 267/30849 [02:45<4:33:21,  1.86it/s]
# Failed to retrieve data for nan
# Extracting Families...:   1%|          | 269/30849 [02:46<4:43:25,  1.80it/s]
# Failed to retrieve data for nan
# Extracting Families...:   1%|          | 286/30849 [02:56<4:48:46,  1.76it/s]
# Failed to retrieve data for nan
# Extracting Families...:   1%|          | 300/30849 [03:05<5:10:02,  1.64it/s]
# Processed 300 proteins...
# Extracting Families...:   1%|          | 302/30849 [03:06<4:53:37,  1.73it/s]
# Failed to retrieve data for nan
# Extracting Families...:   1%|          | 313/30849 [03:13<5:06:34,  1.66it/s]
# Failed to retrieve data for nan
# Extracting Families...:   1%|          | 369/30849 [03:46<4:42:54,  1.80it/s]
# Failed to retrieve data for nan
# Extracting Families...:   1%|▏         | 400/30849 [04:05<4:58:21,  1.70it/s]
# Processed 400 proteins...
# Extracting Families...:   1%|▏         | 433/30849 [04:25<4:31:53,  1.86it/s]
# Failed to retrieve data for nan
# Extracting Families...:   1%|▏         | 440/30849 [04:29<4:36:59,  1.83it/s]
# Failed to retrieve data for nan
# Extracting Families...:   1%|▏         | 446/30849 [04:32<5:04:10,  1.67it/s]
# Failed to retrieve data for nan
# Extracting Families...:   2%|▏         | 500/30849 [05:06<5:28:41,  1.54it/s]
# Processed 500 proteins...
# Extracting Families...:   2%|▏         | 600/30849 [06:06<5:01:16,  1.67it/s]
# Processed 600 proteins...
# Extracting Families...:   2%|▏         | 632/30849 [06:24<4:29:59,  1.87it/s]
# Failed to retrieve data for nan
# Extracting Families...:   2%|▏         | 645/30849 [06:32<4:57:11,  1.69it/s]
# Failed to retrieve data for nan
# Extracting Families...:   2%|▏         | 654/30849 [06:37<4:45:38,  1.76it/s]
# Failed to retrieve data for nan
# Extracting Families...:   2%|▏         | 682/30849 [06:54<4:59:30,  1.68it/s]
# Failed to retrieve data for nan
# Extracting Families...:   2%|▏         | 700/30849 [07:05<5:22:14,  1.56it/s]
# Processed 700 proteins...
# Extracting Families...:   3%|▎         | 800/30849 [08:07<4:49:37,  1.73it/s]
# Processed 800 proteins...
# Extracting Families...:   3%|▎         | 842/30849 [08:32<4:44:37,  1.76it/s]
# Failed to retrieve data for nan
# Extracting Families...:   3%|▎         | 900/30849 [09:06<5:16:42,  1.58it/s]
# Processed 900 proteins...
# Extracting Families...:   3%|▎         | 1000/30849 [10:05<4:39:59,  1.78it/s]
# Processed 1000 proteins...
# Extracting Families...:   3%|▎         | 1016/30849 [10:14<4:23:22,  1.89it/s]
# Failed to retrieve data for nan
# Extracting Families...:   4%|▎         | 1100/30849 [11:02<4:34:25,  1.81it/s]
# Processed 1100 proteins...
# Extracting Families...:   4%|▍         | 1180/30849 [11:51<5:01:04,  1.64it/s]
# Failed to retrieve data for nan
# Extracting Families...:   4%|▍         | 1182/30849 [11:52<4:37:55,  1.78it/s]
# Failed to retrieve data for nan
# Extracting Families...:   4%|▍         | 1182/30849 [11:52<4:58:13,  1.66it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-11-517524513.py in <cell line: 0>()
#       1 # This was executed in a cluster due to colab computational limitations
# ----> 2 plinder_families = extract_families(plinder_uniprot['uniprot_id'])
#
# /tmp/ipython-input-3-2761617287.py in extract_families(uniprot_ids)
#      63
#      64       # Delay to avoid API rate limits
# ---> 65       time.sleep(0.1)
#      66
#      67   # Sorting families by frequency (descending)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Create in-domain and out-domain inference sets

# %% [markdown]
# Read plinder_pfam, add family name

# %%
plinder_pfam_unique = pd.read_csv('/content/drive/MyDrive/Binder_Generation/protein_pocket_analysis/plinder_pfams.csv', index_col=0)

# %%
plinder_pfam_unique
# Out:
#      Protein_ID Pfam_Families
# 0        P68688       PF00462
# 1        P00811       PF00144
# 2        P00390       PF07992
# 3        Q8K4V6       PF00047
# 4        P0DTD1       PF13087
# ...         ...           ...
# 6674     O92367       PF03996
# 6675     A2WPN7       PF01419
# 6676     Q8YSD9       PF09150
# 6677     Q91XX0       PF00028
# 6678     A2V759       PF02225
#
# [6679 rows x 2 columns]

# %%
# Pfams with family name
pfam_df = pd.read_csv("/content/drive/MyDrive/Binder_Generation/protein_pocket_analysis/Pfam-A.clans.tsv.gz", sep='\t', names=['pfam_id', 'pfam_cl_id', 'pfam_name', 'clan_id', 'clan_name'])
pfam_df
# Out:
#        pfam_id pfam_cl_id      pfam_name          clan_id  \
# 0      PF00001     CL0192         GPCR_A            7tm_1
# 1      PF00002     CL0192         GPCR_A            7tm_2
# 2      PF00003     CL0192         GPCR_A            7tm_3
# 3      PF00004     CL0023  P-loop_NTPase              AAA
# 4      PF00005     CL0023  P-loop_NTPase         ABC_tran
# ...        ...        ...            ...              ...
# 24419  PF25508        NaN            NaN            TRPM2
# 24420  PF25509     CL0036     TIM_barrel          DUF7916
# 24421  PF25510     CL0072      Ubiquitin  Ubiquitin_DCDC1
# 24422  PF25511     CL0159          E-set       Ig_CNNM4_N
# 24423  PF25512     CL0537        CCCH_zf  zf-CCCH_AtC3H23
#
#                                                clan_name
# 0            7 transmembrane receptor (rhodopsin family)
# 1             7 transmembrane receptor (Secretin family)
# 2         7 transmembrane sweet-taste receptor of 3 GCPR
# 3      ATPase family associated with various cellular...
# 4                                        ABC transporter
# ...                                                  ...
# 24419                                  TRPM2-like domain
# 24420               Domain of unknown function (DUF7916)
# 24421  Doublecortin domain-containing protein 1-like,...
# 24422  Metal transporter CNNM4-like, immunoglobulin-l...
# 24423                     AtC3H23-like, CCCH zinc finger
#
# [24424 rows x 5 columns]

# %%
pfam_df_merged = plinder_pfam_unique.merge(pfam_df[['pfam_id', 'pfam_name', 'clan_name']], left_on='Pfam_Families', right_on='pfam_id', how='left')
pfam_df_merged
# Out:
#      Protein_ID Pfam_Families  pfam_id       pfam_name  \
# 0        P68688       PF00462  PF00462     Thioredoxin
# 1        P00811       PF00144  PF00144  Beta-lactamase
# 2        P00390       PF07992  PF07992   NADP_Rossmann
# 3        Q8K4V6       PF00047  PF00047           E-set
# 4        P0DTD1       PF13087  PF13087   P-loop_NTPase
# ...         ...           ...      ...             ...
# 6674     O92367       PF03996  PF03996  SGNH_hydrolase
# 6675     A2WPN7       PF01419  PF01419      Man_lectin
# 6676     Q8YSD9       PF09150  PF09150             NaN
# 6677     Q91XX0       PF00028  PF00028           E-set
# 6678     A2V759       PF02225  PF02225        Leu-IlvD
#
#                                           clan_name
# 0                                      Glutaredoxin
# 1                                    Beta-lactamase
# 2     Pyridine nucleotide-disulphide oxidoreductase
# 3                             Immunoglobulin domain
# 4                                        AAA domain
# ...                                             ...
# 6674                         Hemagglutinin esterase
# 6675                     Jacalin-like lectin domain
# 6676         Orange carotenoid protein, N-terminal
# 6677                                Cadherin domain
# 6678                                      PA domain
#
# [6679 rows x 5 columns]

# %%
plinder_uniprot_pfam = pd.merge(pdb_uniprot, pfam_df_merged, left_on='uniprot_id', right_on='Protein_ID')
plinder_uniprot_pfam = plinder_uniprot_pfam.drop('Protein_ID', axis=1)
plinder_uniprot_pfam
# Out:
#       pdb_id uniprot_id Pfam_Families  pfam_id   pfam_name  \
# 0       103M     P02185       PF00042  PF00042      Globin
# 1       107M     P02185       PF00042  PF00042      Globin
# 2       108M     P02185       PF00042  PF00042      Globin
# 3       11BG     P00669       PF00074  PF00074         NaN
# 4       1A00     P68871       PF00042  PF00042      Globin
# ...      ...        ...           ...      ...         ...
# 42920   9ICS     P06746       PF14792  PF14792  NTP_transf
# 42921   9ICT     P06746       PF14792  PF14792  NTP_transf
# 42922   9NSE     P29473       PF00667  PF00667      Hybrid
# 42923   9RSA     P61823       PF00074  PF00074         NaN
# 42924   9RUB     P04718       PF00016  PF00016  TIM_barrel
#
#                                                clan_name
# 0                                                 Globin
# 1                                                 Globin
# 2                                                 Globin
# 3                                Pancreatic ribonuclease
# 4                                                 Globin
# ...                                                  ...
# 42920                          DNA polymerase beta palm
# 42921                          DNA polymerase beta palm
# 42922                                 FAD binding domain
# 42923                            Pancreatic ribonuclease
# 42924  Ribulose bisphosphate carboxylase large chain,...
#
# [42925 rows x 6 columns]

# %%
# loading Plinder Data (train+valid+test split)

plinder = pd.read_csv('/content/drive/MyDrive/Binder_Generation/protein_pocket_analysis/plinder_pocket_data_only1_ligands.csv')
plinder
# Out:
#        pdb_id                       ligand_id  Label  split  \
# 0        1grx          1grx__1__1.A__1.B__1.B      1  train
# 1        3grj          3grj__1__1.A__1.H__1.H      1  train
# 2        2grt      2grt__1__1.A_2.A__1.C__1.C      1  train
# 3        2grt      2grt__1__1.A_2.A__2.C__1.C      1  train
# 4        6grq          6grq__1__1.A__1.B__1.B      1  train
# ...       ...                             ...    ...    ...
# 128842   5ib9  5ib9__1__1.A__1.B_1.C_1.H__1.H      1   test
# 128843   5ib9  5ib9__1__2.A__2.B_2.C_2.H__1.H      1   test
# 128844   4xpp          4xpp__1__2.A__2.B__1.B      1   test
# 128845   3ug6  3ug6__1__1.C_1.D__1.M_1.N__1.M      1   test
# 128846   2y8l          2y8l__1__1.C__1.E__1.E      1   test
#
#                        pocket_key  \
# 0               1grx__1__1.A__1.B
# 1               3grj__1__1.A__1.H
# 2           2grt__1__1.A_2.A__1.C
# 3           2grt__1__1.A_2.A__2.C
# 4               6grq__1__1.A__1.B
# ...                           ...
# 128842  5ib9__1__1.A__1.B_1.C_1.H
# 128843  5ib9__1__2.A__2.B_2.C_2.H
# 128844          4xpp__1__2.A__2.B
# 128845  3ug6__1__1.C_1.D__1.M_1.N
# 128846          2y8l__1__1.C__1.E
#
#                                            cleaned_smiles
# 0          N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(=O)O)C(=O)O
# 1                            O=C(O)C1=CNC(C2=CC=CC=C2)=N1
# 2       N[C@@H](CCC(=O)N[C@@H](CSSC[C@H](NC(=O)CC[C@H]...
# 3       N[C@@H](CCC(=O)N[C@@H](CSSC[C@H](NC(=O)CC[C@H]...
# 4       CC(=O)N[C@H]1[C@H](O[C@H]2[C@H](O)[C@@H](NC(C)...
# ...                                                   ...
# 128842  CC(C)C[C@H](NC(=O)[C@@H](O)[C@H](N)CC1=CC=CC=C...
# 128843  CC(C)C[C@H](NC(=O)[C@@H](O)[C@H](N)CC1=CC=CC=C...
# 128844         OC[C@H]1O[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O
# 128845  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@](=O)(O)O...
# 128846  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@](=O)(O)O...
#
# [128847 rows x 6 columns]

# %%
plinder['pdb_id'] = plinder['pdb_id'].str.upper()
plinder
# Out:
#        pdb_id                       ligand_id  Label  split  \
# 0        1GRX          1grx__1__1.A__1.B__1.B      1  train
# 1        3GRJ          3grj__1__1.A__1.H__1.H      1  train
# 2        2GRT      2grt__1__1.A_2.A__1.C__1.C      1  train
# 3        2GRT      2grt__1__1.A_2.A__2.C__1.C      1  train
# 4        6GRQ          6grq__1__1.A__1.B__1.B      1  train
# ...       ...                             ...    ...    ...
# 128842   5IB9  5ib9__1__1.A__1.B_1.C_1.H__1.H      1   test
# 128843   5IB9  5ib9__1__2.A__2.B_2.C_2.H__1.H      1   test
# 128844   4XPP          4xpp__1__2.A__2.B__1.B      1   test
# 128845   3UG6  3ug6__1__1.C_1.D__1.M_1.N__1.M      1   test
# 128846   2Y8L          2y8l__1__1.C__1.E__1.E      1   test
#
#                        pocket_key  \
# 0               1grx__1__1.A__1.B
# 1               3grj__1__1.A__1.H
# 2           2grt__1__1.A_2.A__1.C
# 3           2grt__1__1.A_2.A__2.C
# 4               6grq__1__1.A__1.B
# ...                           ...
# 128842  5ib9__1__1.A__1.B_1.C_1.H
# 128843  5ib9__1__2.A__2.B_2.C_2.H
# 128844          4xpp__1__2.A__2.B
# 128845  3ug6__1__1.C_1.D__1.M_1.N
# 128846          2y8l__1__1.C__1.E
#
#                                            cleaned_smiles
# 0          N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(=O)O)C(=O)O
# 1                            O=C(O)C1=CNC(C2=CC=CC=C2)=N1
# 2       N[C@@H](CCC(=O)N[C@@H](CSSC[C@H](NC(=O)CC[C@H]...
# 3       N[C@@H](CCC(=O)N[C@@H](CSSC[C@H](NC(=O)CC[C@H]...
# 4       CC(=O)N[C@H]1[C@H](O[C@H]2[C@H](O)[C@@H](NC(C)...
# ...                                                   ...
# 128842  CC(C)C[C@H](NC(=O)[C@@H](O)[C@H](N)CC1=CC=CC=C...
# 128843  CC(C)C[C@H](NC(=O)[C@@H](O)[C@H](N)CC1=CC=CC=C...
# 128844         OC[C@H]1O[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O
# 128845  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@](=O)(O)O...
# 128846  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@](=O)(O)O...
#
# [128847 rows x 6 columns]

# %%
metadata_pfam = pd.merge(plinder, plinder_uniprot_pfam, on='pdb_id', how='left')
metadata_pfam
# Out:
#        pdb_id                       ligand_id  Label  split  \
# 0        1GRX          1grx__1__1.A__1.B__1.B      1  train
# 1        3GRJ          3grj__1__1.A__1.H__1.H      1  train
# 2        2GRT      2grt__1__1.A_2.A__1.C__1.C      1  train
# 3        2GRT      2grt__1__1.A_2.A__2.C__1.C      1  train
# 4        6GRQ          6grq__1__1.A__1.B__1.B      1  train
# ...       ...                             ...    ...    ...
# 148307   5IB9  5ib9__1__2.A__2.B_2.C_2.H__1.H      1   test
# 148308   4XPP          4xpp__1__2.A__2.B__1.B      1   test
# 148309   3UG6  3ug6__1__1.C_1.D__1.M_1.N__1.M      1   test
# 148310   2Y8L          2y8l__1__1.C__1.E__1.E      1   test
# 148311   2Y8L          2y8l__1__1.C__1.E__1.E      1   test
#
#                        pocket_key  \
# 0               1grx__1__1.A__1.B
# 1               3grj__1__1.A__1.H
# 2           2grt__1__1.A_2.A__1.C
# 3           2grt__1__1.A_2.A__2.C
# 4               6grq__1__1.A__1.B
# ...                           ...
# 148307  5ib9__1__2.A__2.B_2.C_2.H
# 148308          4xpp__1__2.A__2.B
# 148309  3ug6__1__1.C_1.D__1.M_1.N
# 148310          2y8l__1__1.C__1.E
# 148311          2y8l__1__1.C__1.E
#
#                                            cleaned_smiles  uniprot_id  \
# 0          N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(=O)O)C(=O)O      P68688
# 1                            O=C(O)C1=CNC(C2=CC=CC=C2)=N1      P00811
# 2       N[C@@H](CCC(=O)N[C@@H](CSSC[C@H](NC(=O)CC[C@H]...      P00390
# 3       N[C@@H](CCC(=O)N[C@@H](CSSC[C@H](NC(=O)CC[C@H]...      P00390
# 4       CC(=O)N[C@H]1[C@H](O[C@H]2[C@H](O)[C@@H](NC(C)...      Q8K4V6
# ...                                                   ...         ...
# 148307  CC(C)C[C@H](NC(=O)[C@@H](O)[C@H](N)CC1=CC=CC=C...      A2V759
# 148308         OC[C@H]1O[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O  A0A0F7R6D6
# 148309  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@](=O)(O)O...      Q58542
# 148310  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@](=O)(O)O...      O43741
# 148311  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@](=O)(O)O...      P54645
#
#        Pfam_Families  pfam_id       pfam_name  \
# 0            PF00462  PF00462     Thioredoxin
# 1            PF00144  PF00144  Beta-lactamase
# 2            PF07992  PF07992   NADP_Rossmann
# 3            PF07992  PF07992   NADP_Rossmann
# 4            PF00047  PF00047           E-set
# ...              ...      ...             ...
# 148307       PF02225  PF02225        Leu-IlvD
# 148308       PF17137  PF17137             NaN
# 148309       PF02374  PF02374   P-loop_NTPase
# 148310       PF16561  PF16561             GHD
# 148311       PF16579  PF16579        KA1-like
#
#                                                 clan_name
# 0                                            Glutaredoxin
# 1                                          Beta-lactamase
# 2           Pyridine nucleotide-disulphide oxidoreductase
# 3           Pyridine nucleotide-disulphide oxidoreductase
# 4                                   Immunoglobulin domain
# ...                                                   ...
# 148307                                          PA domain
# 148308               Domain of unknown function (DUF5110)
# 148309                          Anion-transporting ATPase
# 148310  Glycogen recognition site of AMP-activated pro...
# 148311       Adenylate sensor of SNF1-like protein kinase
#
# [148312 rows x 11 columns]

# %%
metadata_pfam = metadata_pfam.drop_duplicates(subset='ligand_id')
metadata_pfam
# Out:
#        pdb_id                       ligand_id  Label  split  \
# 0        1GRX          1grx__1__1.A__1.B__1.B      1  train
# 1        3GRJ          3grj__1__1.A__1.H__1.H      1  train
# 2        2GRT      2grt__1__1.A_2.A__1.C__1.C      1  train
# 3        2GRT      2grt__1__1.A_2.A__2.C__1.C      1  train
# 4        6GRQ          6grq__1__1.A__1.B__1.B      1  train
# ...       ...                             ...    ...    ...
# 148306   5IB9  5ib9__1__1.A__1.B_1.C_1.H__1.H      1   test
# 148307   5IB9  5ib9__1__2.A__2.B_2.C_2.H__1.H      1   test
# 148308   4XPP          4xpp__1__2.A__2.B__1.B      1   test
# 148309   3UG6  3ug6__1__1.C_1.D__1.M_1.N__1.M      1   test
# 148310   2Y8L          2y8l__1__1.C__1.E__1.E      1   test
#
#                        pocket_key  \
# 0               1grx__1__1.A__1.B
# 1               3grj__1__1.A__1.H
# 2           2grt__1__1.A_2.A__1.C
# 3           2grt__1__1.A_2.A__2.C
# 4               6grq__1__1.A__1.B
# ...                           ...
# 148306  5ib9__1__1.A__1.B_1.C_1.H
# 148307  5ib9__1__2.A__2.B_2.C_2.H
# 148308          4xpp__1__2.A__2.B
# 148309  3ug6__1__1.C_1.D__1.M_1.N
# 148310          2y8l__1__1.C__1.E
#
#                                            cleaned_smiles  uniprot_id  \
# 0          N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(=O)O)C(=O)O      P68688
# 1                            O=C(O)C1=CNC(C2=CC=CC=C2)=N1      P00811
# 2       N[C@@H](CCC(=O)N[C@@H](CSSC[C@H](NC(=O)CC[C@H]...      P00390
# 3       N[C@@H](CCC(=O)N[C@@H](CSSC[C@H](NC(=O)CC[C@H]...      P00390
# 4       CC(=O)N[C@H]1[C@H](O[C@H]2[C@H](O)[C@@H](NC(C)...      Q8K4V6
# ...                                                   ...         ...
# 148306  CC(C)C[C@H](NC(=O)[C@@H](O)[C@H](N)CC1=CC=CC=C...      A2V759
# 148307  CC(C)C[C@H](NC(=O)[C@@H](O)[C@H](N)CC1=CC=CC=C...      A2V759
# 148308         OC[C@H]1O[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O  A0A0F7R6D6
# 148309  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@](=O)(O)O...      Q58542
# 148310  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@](=O)(O)O...      O43741
#
#        Pfam_Families  pfam_id       pfam_name  \
# 0            PF00462  PF00462     Thioredoxin
# 1            PF00144  PF00144  Beta-lactamase
# 2            PF07992  PF07992   NADP_Rossmann
# 3            PF07992  PF07992   NADP_Rossmann
# 4            PF00047  PF00047           E-set
# ...              ...      ...             ...
# 148306       PF02225  PF02225        Leu-IlvD
# 148307       PF02225  PF02225        Leu-IlvD
# 148308       PF17137  PF17137             NaN
# 148309       PF02374  PF02374   P-loop_NTPase
# 148310       PF16561  PF16561             GHD
#
#                                                 clan_name
# 0                                            Glutaredoxin
# 1                                          Beta-lactamase
# 2           Pyridine nucleotide-disulphide oxidoreductase
# 3           Pyridine nucleotide-disulphide oxidoreductase
# 4                                   Immunoglobulin domain
# ...                                                   ...
# 148306                                          PA domain
# 148307                                          PA domain
# 148308               Domain of unknown function (DUF5110)
# 148309                          Anion-transporting ATPase
# 148310  Glycogen recognition site of AMP-activated pro...
#
# [122315 rows x 11 columns]

# %%
print('Interactions with pfamily in train split', len(metadata_pfam[metadata_pfam['split'] == 'train']))
print('Interactions with pfamily in val split', len(metadata_pfam[metadata_pfam['split'] == 'val']))
print('Interactions with pfamily in train+val split', len(metadata_pfam[metadata_pfam['split'] == 'val'] + metadata_pfam[metadata_pfam['split'] == 'train']))
print('Interactions with pfamily in test split', len(metadata_pfam[metadata_pfam['split'] == 'test']))
# Out:
# Interactions with pfamily in train split 116644
# Interactions with pfamily in val split 1302
# Interactions with pfamily in train+val split 117946
# Interactions with pfamily in test split 4369

# %%
print('In all Plinder there are', len(metadata_pfam['Pfam_Families'].value_counts()), 'unique families')
print('In all Train+Valid split there are', len(metadata_pfam[metadata_pfam['split'].isin(['train', 'val'])]['Pfam_Families'].value_counts()), 'unique families')
print('In all Test split there are', len(metadata_pfam[metadata_pfam['split']=='test']['Pfam_Families'].value_counts()), 'unique families')
# Out:
# In all Plinder there are 2121 unique families
# In all Train+Valid split there are 1685 unique families
# In all Test split there are 733 unique families

# %%
top_n = 50 # top 20 most frequent
# Count frequencies
pfamily_counts = metadata_pfam['Pfam_Families'].value_counts().head(top_n)


# Plot
plt.figure(figsize=(12, 7))
sns.barplot(x=pfamily_counts.index, y=pfamily_counts.values, palette="viridis")
plt.xlabel("Protein Family")
plt.ylabel("Count")
plt.title("Frequency of Protein Families in all Plinder")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-23-3731549250.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=pfamily_counts.index, y=pfamily_counts.values, palette="viridis")

# %%
top_n = 50 # top 20 most frequent
# Count frequencies
pfamily_counts = metadata_pfam['clan_name'].value_counts().head(top_n)
output_dir = '/content/drive/MyDrive/Binder_Generation/protein_pocket_analysis/plots'

# Plot
plt.figure(figsize=(12, 7))
sns.barplot(y=pfamily_counts.index, x=pfamily_counts.values, palette="viridis")
plt.ylabel("Protein Family")
plt.xlabel("Count")
plt.title("Frequency of Protein Families in all PLINDER")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig(os.path.join(output_dir, f"PLINDER_families_freq.png"), dpi=300,  bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipython-input-25-3619704632.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=pfamily_counts.index, x=pfamily_counts.values, palette="viridis")

# %%
top_n = 50  # top 50 most frequent

# Normalize to frequencies
pfamily_counts = (
    metadata_pfam['clan_name']
    .value_counts(normalize=True)  # Normalize to get relative frequencies
    .head(top_n)            # Convert to percentage
)

# Plot
plt.figure(figsize=(12, 7))
sns.barplot(y=pfamily_counts.index, x=pfamily_counts.values, palette="viridis")
plt.ylabel("Protein Family")
plt.xlabel("Frequency")
plt.title("Relative Frequency of Protein Families in all PLINDER")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig(f"/content/drive/MyDrive/Binder_Generation/protein_pocket_analysis/plots/PLINDER_families_freq.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipython-input-26-2929181385.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=pfamily_counts.index, x=pfamily_counts.values, palette="viridis")

# %%
top_n = 50 # top 20 most frequent
# Count frequencies
pfamily_counts = metadata_pfam['clan_name'].value_counts().head(top_n)


# Plot
plt.figure(figsize=(12, 7))
sns.barplot(x=pfamily_counts.index, y=pfamily_counts.values, palette="viridis")
plt.xlabel("Protein Family")
plt.ylabel("Count")
plt.title("Frequency of Protein Families in all Plinder")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-27-2710252692.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=pfamily_counts.index, y=pfamily_counts.values, palette="viridis")

# %%
# Filter for train or val
filtered_df = metadata_pfam[metadata_pfam['split'].isin(['train', 'val'])]

top_n = 50 # top 20 most frequent
# Count frequencies
pfamily_counts = filtered_df['Pfam_Families'].value_counts().head(top_n)


# Plot
plt.figure(figsize=(12, 7))
sns.barplot(x=pfamily_counts.index, y=pfamily_counts.values, palette="viridis")
plt.xlabel("Protein Family")
plt.ylabel("Count")
plt.title("Frequency of Protein Families in Train+Val Split (in-domain)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-28-3269451668.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=pfamily_counts.index, y=pfamily_counts.values, palette="viridis")

# %%
# Filter for train or val
filtered_df = metadata_pfam[metadata_pfam['split'].isin(['train', 'val'])]

top_n = 50 # top 20 most frequent
# Count frequencies
pfamily_counts = filtered_df['clan_name'].value_counts().head(top_n)


# Plot
plt.figure(figsize=(12, 7))
sns.barplot(x=pfamily_counts.index, y=pfamily_counts.values, palette="viridis")
plt.xlabel("Protein Family")
plt.ylabel("Count")
plt.title("Frequency of Protein Families in Train+Val Split (in-domain)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-29-2327660126.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=pfamily_counts.index, y=pfamily_counts.values, palette="viridis")

# %%
top_n = 50  # top 50 most frequent

# Normalize to frequencies
pfamily_counts = (
    filtered_df['clan_name']
    .value_counts(normalize=True)  # Normalize to get relative frequencies
    .head(top_n)            # Convert to percentage
)

# Plot
plt.figure(figsize=(12, 7))
sns.barplot(y=pfamily_counts.index, x=pfamily_counts.values, palette="viridis")
plt.ylabel("Protein Family")
plt.xlabel("Frequency")
plt.title("Relative Frequency of Protein Families in train+val split PLINDER")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig(f"/content/drive/MyDrive/Binder_Generation/protein_pocket_analysis/plots/PLINDER_traian_families_freq.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipython-input-30-548465736.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=pfamily_counts.index, x=pfamily_counts.values, palette="viridis")

# %%
top_n = 50 # top 20 most frequent
# Count frequencies
pfamily_counts = metadata_pfam[metadata_pfam['split'] == 'test']['clan_name'].value_counts().head(top_n)


# Plot
plt.figure(figsize=(12, 7))
sns.barplot(x=pfamily_counts.index, y=pfamily_counts.values, palette="viridis")
plt.xlabel("Protein Family")
plt.ylabel("Count")
plt.title("Frequency of Protein Families in Test Split (out-domain)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-31-379284944.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=pfamily_counts.index, y=pfamily_counts.values, palette="viridis")

# %%
top_n = 50  # top 50 most frequent
filtered_df = metadata_pfam[metadata_pfam['split'] == 'test']

# Normalize to frequencies
pfamily_counts = (
    filtered_df['clan_name']
    .value_counts(normalize=True)  # Normalize to get relative frequencies
    .head(top_n)            # Convert to percentage
)

# Plot
plt.figure(figsize=(12, 7))
sns.barplot(y=pfamily_counts.index, x=pfamily_counts.values, palette="viridis")
plt.ylabel("Protein Family")
plt.xlabel("Frequency")
plt.title("Relative Frequency of Protein Families in test split PLINDER (out-domain)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig(f"/content/drive/MyDrive/Binder_Generation/protein_pocket_analysis/plots/PLINDER_test_families_freq.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipython-input-32-1508417778.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=pfamily_counts.index, x=pfamily_counts.values, palette="viridis")

# %% [markdown]
# ## Create In-domain subsets

# %%
train_df = metadata_pfam[metadata_pfam['split'].isin(['train', 'val'])]

# %%
# obtain 50 most common
top_50 = 50
top_50_families = train_df['clan_name'].value_counts().head(top_50)

filtered_subset = train_df[train_df['clan_name'].isin(top_50_families.index)]
filtered_subset
# Out:
#        pdb_id                           ligand_id  Label  split  \
# 8        7GRE              7gre__1__1.A__1.C__1.C      1  train
# 9        7GRX          7grx__1__1.B__1.N_1.O__1.N      1  train
# 10       5GRB              5grb__1__1.A__1.G__1.G      1  train
# 11       5GRB              5grb__1__1.C__1.K__1.K      1  train
# 12       5GRB              5grb__1__1.E__1.O__1.O      1  train
# ...       ...                                 ...    ...    ...
# 143589   7DNZ  7dnz__1__1.A_1.B__1.C_1.H_1.I__1.I      1    val
# 143590   7DNZ              7dnz__1__1.A__1.F__1.F      1    val
# 143591   7DNZ              7dnz__1__1.B__1.L__1.L      1    val
# 143592   3LP1  3lp1__2__1.A_2.A__1.C_1.D_1.E__2.C      1    val
# 143593   7LPX              7lpx__1__1.A__1.E__1.E      1    val
#
#                            pocket_key  \
# 8                   7gre__1__1.A__1.C
# 9               7grx__1__1.B__1.N_1.O
# 10                  5grb__1__1.A__1.G
# 11                  5grb__1__1.C__1.K
# 12                  5grb__1__1.E__1.O
# ...                               ...
# 143589  7dnz__1__1.A_1.B__1.C_1.H_1.I
# 143590              7dnz__1__1.A__1.F
# 143591              7dnz__1__1.B__1.L
# 143592  3lp1__2__1.A_2.A__1.C_1.D_1.E
# 143593              7lpx__1__1.A__1.E
#
#                                            cleaned_smiles uniprot_id  \
# 8                          FC(F)(F)C1=NNC(C2=CC=NC=C2)=C1     P0DTD1
# 9                            O=C1CCC(=O)N1C1=CC=C(F)C=C1F     P0DTD1
# 10      NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](COP(=O)(O)OP(=...     B9VUU3
# 11      NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](COP(=O)(O)OP(=...     B9VUU3
# 12      NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](COP(=O)(O)OP(=...     B9VUU3
# ...                                                   ...        ...
# 143589     N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(=O)O)C(=O)O     Q9NP58
# 143590  CC(C)CCC[C@@H](C)[C@H]1CC[C@H]2[C@@H]3CC=C4C[C...     Q9NP58
# 143591  CC(C)CCC[C@@H](C)[C@H]1CC[C@H]2[C@@H]3CC=C4C[C...     Q9NP58
# 143592                  O=C1C(C2CCCC2)=C(O)C2=CC=CN=C2N1O     P04585
# 143593  CC1=C(C(=O)N[C@@H](CN)C2=NC=C(CO)S2)NC(C2=CC=C...     P03366
#
#        Pfam_Families  pfam_id      pfam_name  \
# 8            PF13087  PF13087  P-loop_NTPase
# 9            PF13087  PF13087  P-loop_NTPase
# 10           PF08727  PF08727            NaN
# 11           PF08727  PF08727            NaN
# 12           PF08727  PF08727            NaN
# ...              ...      ...            ...
# 143589       PF00664  PF00664   ABC_membrane
# 143590       PF00664  PF00664   ABC_membrane
# 143591       PF00664  PF00664   ABC_membrane
# 143592       PF00540  PF00540         Matrix
# 143593       PF00540  PF00540         Matrix
#
#                                     clan_name
# 8                                  AAA domain
# 9                                  AAA domain
# 10                 Poliovirus 3A protein like
# 11                 Poliovirus 3A protein like
# 12                 Poliovirus 3A protein like
# ...                                       ...
# 143589   ABC transporter transmembrane region
# 143590   ABC transporter transmembrane region
# 143591   ABC transporter transmembrane region
# 143592  gag gene protein p17 (matrix protein)
# 143593  gag gene protein p17 (matrix protein)
#
# [73997 rows x 11 columns]

# %%
pfamily_counts = filtered_subset['clan_name'].value_counts() # there are already only top 50 families in the df

# Plot
plt.figure(figsize=(12, 7))
sns.barplot(x=pfamily_counts.index, y=pfamily_counts.values, palette="viridis")
plt.xlabel("Protein Family")
plt.ylabel("Count")
plt.title("Frequency of Protein Families in Train+Val Split (in-domain)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# I have been able to replicate the plot so, filtered_subset has the correct top 50 families.
# Out:
# /tmp/ipython-input-35-1322343792.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=pfamily_counts.index, y=pfamily_counts.values, palette="viridis")

# %%
filtered_subset.to_csv('/content/drive/MyDrive/Binder_Generation/protein_pocket_analysis/In-domain_top50_allpdbs.csv')
filtered_subset
# Out:
#        pdb_id                           ligand_id  Label  split  \
# 8        7GRE              7gre__1__1.A__1.C__1.C      1  train
# 9        7GRX          7grx__1__1.B__1.N_1.O__1.N      1  train
# 10       5GRB              5grb__1__1.A__1.G__1.G      1  train
# 11       5GRB              5grb__1__1.C__1.K__1.K      1  train
# 12       5GRB              5grb__1__1.E__1.O__1.O      1  train
# ...       ...                                 ...    ...    ...
# 143589   7DNZ  7dnz__1__1.A_1.B__1.C_1.H_1.I__1.I      1    val
# 143590   7DNZ              7dnz__1__1.A__1.F__1.F      1    val
# 143591   7DNZ              7dnz__1__1.B__1.L__1.L      1    val
# 143592   3LP1  3lp1__2__1.A_2.A__1.C_1.D_1.E__2.C      1    val
# 143593   7LPX              7lpx__1__1.A__1.E__1.E      1    val
#
#                            pocket_key  \
# 8                   7gre__1__1.A__1.C
# 9               7grx__1__1.B__1.N_1.O
# 10                  5grb__1__1.A__1.G
# 11                  5grb__1__1.C__1.K
# 12                  5grb__1__1.E__1.O
# ...                               ...
# 143589  7dnz__1__1.A_1.B__1.C_1.H_1.I
# 143590              7dnz__1__1.A__1.F
# 143591              7dnz__1__1.B__1.L
# 143592  3lp1__2__1.A_2.A__1.C_1.D_1.E
# 143593              7lpx__1__1.A__1.E
#
#                                            cleaned_smiles uniprot_id  \
# 8                          FC(F)(F)C1=NNC(C2=CC=NC=C2)=C1     P0DTD1
# 9                            O=C1CCC(=O)N1C1=CC=C(F)C=C1F     P0DTD1
# 10      NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](COP(=O)(O)OP(=...     B9VUU3
# 11      NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](COP(=O)(O)OP(=...     B9VUU3
# 12      NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](COP(=O)(O)OP(=...     B9VUU3
# ...                                                   ...        ...
# 143589     N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(=O)O)C(=O)O     Q9NP58
# 143590  CC(C)CCC[C@@H](C)[C@H]1CC[C@H]2[C@@H]3CC=C4C[C...     Q9NP58
# 143591  CC(C)CCC[C@@H](C)[C@H]1CC[C@H]2[C@@H]3CC=C4C[C...     Q9NP58
# 143592                  O=C1C(C2CCCC2)=C(O)C2=CC=CN=C2N1O     P04585
# 143593  CC1=C(C(=O)N[C@@H](CN)C2=NC=C(CO)S2)NC(C2=CC=C...     P03366
#
#        Pfam_Families  pfam_id      pfam_name  \
# 8            PF13087  PF13087  P-loop_NTPase
# 9            PF13087  PF13087  P-loop_NTPase
# 10           PF08727  PF08727            NaN
# 11           PF08727  PF08727            NaN
# 12           PF08727  PF08727            NaN
# ...              ...      ...            ...
# 143589       PF00664  PF00664   ABC_membrane
# 143590       PF00664  PF00664   ABC_membrane
# 143591       PF00664  PF00664   ABC_membrane
# 143592       PF00540  PF00540         Matrix
# 143593       PF00540  PF00540         Matrix
#
#                                     clan_name
# 8                                  AAA domain
# 9                                  AAA domain
# 10                 Poliovirus 3A protein like
# 11                 Poliovirus 3A protein like
# 12                 Poliovirus 3A protein like
# ...                                       ...
# 143589   ABC transporter transmembrane region
# 143590   ABC transporter transmembrane region
# 143591   ABC transporter transmembrane region
# 143592  gag gene protein p17 (matrix protein)
# 143593  gag gene protein p17 (matrix protein)
#
# [73997 rows x 11 columns]

# %%
# Sample randomly 1 proteins per pfamily
balanced_subset_top50 = filtered_subset.groupby('clan_name').sample(n=1, random_state=42)

# Now balanced_subset is balanced across pfamilies
balanced_subset_top50.to_csv('/content/drive/MyDrive/Binder_Generation/protein_pocket_analysis/In-domain_top50.csv')
balanced_subset_top50
# Out:
#        pdb_id                           ligand_id  Label  split  \
# 94692    1F88              1f88__3__1.B__1.R__3.R      1  train
# 63793    1LYB              1lyb__1__2.E__2.J__1.J      1  train
# 59586    8CYZ              8cyz__1__1.A__1.E__1.E      1  train
# 108485   7ZEC          7zec__1__1.B__1.D_1.E__1.E      1  train
# 36839    5OG1          5og1__1__1.C_1.D__1.J__1.J      1  train
# 39749    1XLU              1xlu__2__1.A__1.D__2.D      1  train
# 79384    8D15          8d15__1__1.B__1.J_1.K__1.J      1  train
# 58121    6NK6            6nk6__1__51.A__51.Q__1.Q      1  train
# 140535   3PGH              3pgh__1__1.A__1.F__1.F      1  train
# 117313   5IRX              5irx__1__1.D__1.Q__1.Q      1  train
# 31935    1LDO              1ldo__1__2.A__2.D__1.D      1  train
# 15583    5B34              5b34__1__1.A__1.B__1.B      1  train
# 115183   8OHN          8ohn__1__1.A_1.B__1.J__1.J      1  train
# 22745    8AG2              8ag2__1__1.A__1.B__1.B      1  train
# 105209   6V1K              6v1k__1__1.A__1.B__1.B      1  train
# 115964   6U8S      6u8s__1__1.E_1.F__1.S_1.T__1.S      1  train
# 129303   1RB8       1rb8__1__27.A__27.G_53.F__1.F      1  train
# 122217   1AMN              1amn__1__2.A__2.C__1.C      1  train
# 117886   6UNL          6unl__2__4.A__4.B_4.C__2.C      1  train
# 129749   6WH4              6wh4__3__1.C__1.L__3.L      1  train
# 123883   4ELB              4elb__4__1.D__1.T__4.T      1  train
# 90607    2GBC              2gbc__2__3.B__3.J__2.J      1  train
# 2395     4OU3              4ou3__1__1.A__1.L__1.L      1  train
# 75073    7LIT  7lit__1__11.A_16.A_17.A__17.B__1.B      1  train
# 49118    6X9S              6x9s__1__2.A__2.P__1.P      1  train
# 76611    3M2N      3m2n__1__1.A__1.B_1.C_1.E__1.B      1  train
# 30154    7KVA            7kva__1__58.C__58.I__1.I      1  train
# 72000    6WA2              6wa2__1__1.B__1.F__1.F      1  train
# 96990    3WI2              3wi2__1__1.A__1.E__1.E      1  train
# 4288     5AKV          5akv__1__1.A_2.A__1.C__1.C      1  train
# 70788    6NSC              6nsc__1__2.A__1.E__1.E      1  train
# 65566    6WFS       6wfs__1__34.D_35.B__34.H__1.H      1  train
# 35042    1QFU              1qfu__1__3.B__3.I__1.I      1  train
# 107329   7CZP              7czp__1__1.B__1.S__1.S      1  train
# 122737   7WRD              7wrd__1__1.D__1.L__1.L      1  train
# 42565    2D7F              2d7f__2__1.C__1.M__2.M      1  train
# 103697   6DKW              6dkw__1__1.A__1.C__1.C      1  train
# 4654     5Z12              5z12__1__1.G__1.L__1.L      1  train
# 137014   4GEZ              4gez__1__1.A__1.T__1.T      1  train
# 54745    8BHO          8bho__1__1.D_1.E__1.O__1.O      1  train
# 61109    1CX8              1cx8__1__1.A__1.K__1.K      1  train
# 88345    3KIC              3kic__3__2.F__2.Z__3.Z      1  train
# 4958     2RS1            2rs1__1__15.A__15.E__1.E      1  train
# 138408   7FHT              7fht__4__1.D__1.H__4.H      1  train
# 56041    5UAB              5uab__1__1.A__1.B__1.B      1  train
# 85879    6NTC          6ntc__1__1.A__1.C_1.E__1.C      1  train
# 56844    6RUQ          6ruq__1__1.C_1.D__1.L__1.L      1  train
# 133270   7X3U              7x3u__1__1.A__1.Q__1.Q      1  train
# 111405   6B0C          6b0c__1__5.E__5.M_5.N__1.N      1  train
# 131277   3C6T              3c6t__1__1.A__1.C__1.C      1  train
#
#                            pocket_key  \
# 94692               1f88__3__1.B__1.R
# 63793               1lyb__1__2.E__2.J
# 59586               8cyz__1__1.A__1.E
# 108485          7zec__1__1.B__1.D_1.E
# 36839           5og1__1__1.C_1.D__1.J
# 39749               1xlu__2__1.A__1.D
# 79384           8d15__1__1.B__1.J_1.K
# 58121             6nk6__1__51.A__51.Q
# 140535              3pgh__1__1.A__1.F
# 117313              5irx__1__1.D__1.Q
# 31935               1ldo__1__2.A__2.D
# 15583               5b34__1__1.A__1.B
# 115183          8ohn__1__1.A_1.B__1.J
# 22745               8ag2__1__1.A__1.B
# 105209              6v1k__1__1.A__1.B
# 115964      6u8s__1__1.E_1.F__1.S_1.T
# 129303       1rb8__1__27.A__27.G_53.F
# 122217              1amn__1__2.A__2.C
# 117886          6unl__2__4.A__4.B_4.C
# 129749              6wh4__3__1.C__1.L
# 123883              4elb__4__1.D__1.T
# 90607               2gbc__2__3.B__3.J
# 2395                4ou3__1__1.A__1.L
# 75073   7lit__1__11.A_16.A_17.A__17.B
# 49118               6x9s__1__2.A__2.P
# 76611       3m2n__1__1.A__1.B_1.C_1.E
# 30154             7kva__1__58.C__58.I
# 72000               6wa2__1__1.B__1.F
# 96990               3wi2__1__1.A__1.E
# 4288            5akv__1__1.A_2.A__1.C
# 70788               6nsc__1__2.A__1.E
# 65566        6wfs__1__34.D_35.B__34.H
# 35042               1qfu__1__3.B__3.I
# 107329              7czp__1__1.B__1.S
# 122737              7wrd__1__1.D__1.L
# 42565               2d7f__2__1.C__1.M
# 103697              6dkw__1__1.A__1.C
# 4654                5z12__1__1.G__1.L
# 137014              4gez__1__1.A__1.T
# 54745           8bho__1__1.D_1.E__1.O
# 61109               1cx8__1__1.A__1.K
# 88345               3kic__3__2.F__2.Z
# 4958              2rs1__1__15.A__15.E
# 138408              7fht__4__1.D__1.H
# 56041               5uab__1__1.A__1.B
# 85879           6ntc__1__1.A__1.C_1.E
# 56844           6ruq__1__1.C_1.D__1.L
# 133270              7x3u__1__1.A__1.Q
# 111405          6b0c__1__5.E__5.M_5.N
# 131277              3c6t__1__1.A__1.C
#
#                                            cleaned_smiles  uniprot_id  \
# 94692               CC(C=CC=C(C)C=CC1=C(C)CCCC1(C)C)=CC=O      P02699
# 63793   CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O      P07339
# 59586   CSC1=CC=C(N(CC2=CC(Cl)=CS2)C(=O)CC2=CN=CC3=CC=...      P0DTD1
# 108485  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@@](=O)(O)...      P23886
# 36839   NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](COP(=O)(O)OP(=...      P0ABH9
# 39749   CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O      P06276
# 79384   NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@](=O)(O)O...      P68139
# 58121   CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O      Q5XXP3
# 140535  CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O      Q05769
# 117313  CCCCCC(=O)O[C@@H](COC(=O)CCCC)COP(=O)(O)OCC[N+...      O35433
# 31935            O=C(O)CCC[C@@H]1SC[C@@H]2NC(=O)N[C@@H]21      P02701
# 15583               CC(C=CC=C(C)C=CC1=C(C)CCCC1(C)C)=CC=O      P02945
# 115183  CC(=O)N[C@H]1[C@H](O[C@H]2[C@H](O)[C@@H](NC(C)...      E0YJ44
# 22745   COC1=CC(C2=CN(C)C(=O)C(C)=C2C)=CC=C1C1(N2CCN(C...      Q12830
# 105209  COC1=CC(C2=CN(C)C(=O)C3=CN=CC=C23)=CC(OC)=C1CN...      O60885
# 115964  O=C1NC=NC2=C1N=CN2[C@@H]1O[C@H](COP(=O)(O)O)[C...      P12268
# 129303  NC1=NC(=O)N([C@H]2C[C@H](O)[C@@H](COP(=O)(O)O)...      P08767
# 122217            C[N+](C)(C)C1=CC=CC(C(O)(O)C(F)(F)F)=C1      P04058
# 117886  CC(C)(C)OC(=O)N[C@@H](CS[C@@H](CC1=CC=CC2=CC=C...      P08684
# 129749     CSC1=CC=C2SC3=CC=CC=C3C[C@H](N3CCN(C)CC3)C2=C1      P0ABE7
# 123883  COC1=CC(CC2=CN=C(N)N=C2N)=CC(C=CC(=O)N2N=CC3=C...      Q81R22
# 90607   CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O      P14740
# 2395    CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O      P15145
# 75073   CC1=CC2=C(C=C1C)N(C[C@H](O)[C@H](O)[C@H](O)CO)...      Q9WZP2
# 49118   CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O      Q2N0S6
# 76611   NS(=O)(=O)C1=CC=C(CCNC2=NC=NC(Cl)=C2[N+](=O)[O...      P00918
# 30154   CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O      P14335
# 72000   CSC1=NC(C2=CC=CC(NC(=O)C3=CC(O)=CC=C3F)=C2)=C(...      P00533
# 96990   CC(C)C1=NC2=CC=C(OCC3=CC=C4C=CC=CC4=N3)C=C2N1C...      Q9Y233
# 4288    O=C(O)[C@H]1O[C@@H](OC2=CC(O)=C3C(=O)C(C4=CC=C...      P02766
# 70788   CC(=O)N[C@H]1[C@H](O[C@H]2[C@H](O)[C@@H](NC(C)...      A8W891
# 65566   NS(=O)(=O)C1=CC=C(CCNC(=O)C2=CC=C3SC4=CC=CC=C4...      P03147
# 35042   CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O      A2NHM3
# 107329  CC(=O)N[C@H]1[C@H](O[C@H]2[C@H](O)[C@@H](NC(C)...  A0A5C2GM57
# 122737  O=C1NC(C2=CC=CC([N+](=O)[O-])=C2)=CCN1C1=CC=CC...      Q8R4D5
# 42565         CO[C@H]1O[C@H](CO)[C@@H](O)[C@H](O)[C@@H]1O      P14894
# 103697  CN1C=NC(C2=CC=C(OC3CCN(C(=O)CC4=CC=C(OC(F)(F)F...      P04629
# 4654             CC(C=CC1=C(C)CCCC1(C)C)=CC=CC(C)=CC(=O)O      P19793
# 137014  CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O      H6QM85
# 54745   CCOC(=O)C1=C2[C@@H]3CCCN3C(=O)C3=CC(OC)=CC=C3N...      P31644
# 61109   CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O      P02786
# 88345   NC1=NC=NC2=C1N=CN2[C@H]1C[C@H](O)[C@@H](COP(=O...      O56139
# 4958    CC1=NOC(CCCCCCCOC2=CC=C(C3=N[C@@H](C)CO3)C=C2)=C1      P03303
# 138408                  C#CC1=CC(C=C2SC(=S)NC2=O)=CC=C1OC      Q13627
# 56041    O=C(NC1=CN2N=C(SC3=NN=C4C=CC=CN34)C=CC2=N1)C1CC1      P08581
# 85879   NC1=NC2=C(N=CN2[C@@H]2O[C@H](CO[P@](=O)(O)O[P@...      P01112
# 56844   CNC(=O)N1N=C(C2=CC=C(N)C=C2)C2=CC3=C(C=C2C[C@H...      P19491
# 133270  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@](=O)(O)O...      P17987
# 111405  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@](=O)(O)O...      P02554
# 131277  N#CC1=CC(Cl)=CC(OC2=CC(Cl)=CC(OCC(=O)NC3=CC=C(...      P04585
#
#        Pfam_Families  pfam_id        pfam_name  \
# 94692        PF00001  PF00001           GPCR_A
# 63793        PF07966  PF07966              NaN
# 59586        PF13087  PF13087    P-loop_NTPase
# 108485       PF00664  PF00664     ABC_membrane
# 36839        PF00004  PF00004    P-loop_NTPase
# 39749        PF08674  PF08674              NaN
# 79384        PF00022  PF00022     Actin_ATPase
# 58121        PF01589  PF01589  Viral_gly_cn_dm
# 140535       PF03098  PF03098       Peroxidase
# 117313       PF00023  PF00023              Ank
# 31935        PF01382  PF01382              NaN
# 15583        PF01036  PF01036           GPCR_A
# 115183       PF16451  PF16451     Concanavalin
# 22745        PF00439  PF00439              NaN
# 105209       PF17035  PF17035              BET
# 115964       PF00571  PF00571              NaN
# 129303       PF02305  PF02305      ssDNA_NP_VP
# 122217       PF00135  PF00135     AB_hydrolase
# 117886       PF00067  PF00067              NaN
# 129749       PF07361  PF07361              NaN
# 123883       PF00186  PF00186           DHFred
# 90607        PF00930  PF00930   Beta_propeller
# 2395         PF11838  PF11838            E-set
# 75073        PF04454  PF04454       Phage-coat
# 49118        PF00516  PF00516              NaN
# 76611        PF00194  PF00194              NaN
# 30154        PF20907  PF20907              NaN
# 72000        PF00757  PF00757  GF_recep_C-rich
# 96990        PF01590  PF01590              GAF
# 4288         PF00576  PF00576    Transthyretin
# 70788        PF00509  PF00509              NaN
# 65566        PF00906  PF00906              NaN
# 35042        PF07654  PF07654            E-set
# 107329       PF07686  PF07686            E-set
# 122737       PF00520  PF00520      Ion_channel
# 42565        PF00139  PF00139     Concanavalin
# 103697       PF13855  PF13855              LRR
# 4654         PF00104  PF00104              NaN
# 137014       PF00064  PF00064   Beta_propeller
# 54745        PF02931  PF02931              NaN
# 61109        PF02225  PF02225         Leu-IlvD
# 88345        PF00740  PF00740      ssDNA_NP_VP
# 4958         PF08727  PF08727              NaN
# 138408       PF00069  PF00069          PKinase
# 56041        PF07714  PF07714          PKinase
# 85879        PF00071  PF00071    P-loop_NTPase
# 56844        PF01094  PF01094      Periplas_BP
# 133270       PF00118  PF00118              NaN
# 111405       PF00091  PF00091    NADP_Rossmann
# 131277       PF00540  PF00540           Matrix
#
#                                                 clan_name
# 94692         7 transmembrane receptor (rhodopsin family)
# 63793                                      A1 Propeptide
# 59586                                          AAA domain
# 108485               ABC transporter transmembrane region
# 36839   ATPase family associated with various cellular...
# 39749         Acetylcholinesterase tetramerisation domain
# 79384                                               Actin
# 58121                          Alphavirus E1 glycoprotein
# 140535                             Animal haem peroxidase
# 117313                                     Ankyrin repeat
# 31935                                       Avidin family
# 15583                      Bacteriorhodopsin-like protein
# 115183  Betacoronavirus-like spike glycoprotein S1, N-...
# 22745                                         Bromodomain
# 105209  Bromodomain extra-terminal - transcription reg...
# 115964                                         CBS domain
# 129303                         Capsid protein (F protein)
# 122217                            Carboxylesterase family
# 117886                                    Cytochrome P450
# 129749                                    Cytochrome b562
# 123883                            Dihydrofolate reductase
# 90607   Dipeptidyl peptidase IV (DPP IV) N-terminal re...
# 2395                         ERAP1-like C-terminal domain
# 75073                Encapsulating protein for peroxidase
# 49118                         Envelope glycoprotein GP120
# 76611                  Eukaryotic-type carbonic anhydrase
# 30154   Flavivirus NS3 helicase, C-terminal helical do...
# 72000                     Furin-like cysteine rich region
# 96990                                          GAF domain
# 4288                          HIUase/Transthyretin family
# 70788                                      Haemagglutinin
# 65566                              Hepatitis core antigen
# 35042                        Immunoglobulin C1-set domain
# 107329                        Immunoglobulin V-set domain
# 122737                              Ion transport protein
# 42565                                Legume lectin domain
# 103697                                Leucine rich repeat
# 4654    Ligand-binding domain of nuclear hormone receptor
# 137014                                      Neuraminidase
# 54745   Neurotransmitter-gated ion-channel ligand bind...
# 61109                                           PA domain
# 88345                         Parvovirus coat protein VP2
# 4958                           Poliovirus 3A protein like
# 138408                              Protein kinase domain
# 56041        Protein tyrosine and serine/threonine kinase
# 85879                                          Ras family
# 56844               Receptor family ligand binding region
# 133270                      TCP-1/cpn60 chaperonin family
# 111405                 Tubulin/FtsZ family, GTPase domain
# 131277              gag gene protein p17 (matrix protein)

# %% [markdown]
# ### Cleaning top5 viruses

# %%
# all plinder

# disregard the first 5 protein families which correspond to family of viruses proteins
top_n = 5

# Get top N frequent clan_names
top_pfamilies = metadata_pfam['clan_name'].value_counts().head(top_n).index

# Filter out rows with those clan_names
filtered_subset = metadata_pfam[~metadata_pfam['clan_name'].isin(top_pfamilies)]
filtered_subset

filtered_subset.to_csv('/content/drive/MyDrive/Binder_Generation/protein_pocket_analysis/plinder_no_virus.csv')

# %%
# disregard the first 5 protein families which correspond to family of viruses proteins
top_n = 5

# Get top N frequent clan_names
top_pfamilies = train_df['clan_name'].value_counts().head(top_n).index

# Filter out rows with those clan_names
filtered_subset = train_df[~train_df['clan_name'].isin(top_pfamilies)]
filtered_subset
# Out:
#        pdb_id                   ligand_id  Label  split  \
# 0        1GRX      1grx__1__1.A__1.B__1.B      1  train
# 1        3GRJ      3grj__1__1.A__1.H__1.H      1  train
# 2        2GRT  2grt__1__1.A_2.A__1.C__1.C      1  train
# 3        2GRT  2grt__1__1.A_2.A__2.C__1.C      1  train
# 4        6GRQ      6grq__1__1.A__1.B__1.B      1  train
# ...       ...                         ...    ...    ...
# 143865   3EJA      3eja__1__1.A__1.E__1.E      1    val
# 143866   7KW2      7kw2__1__1.A__1.C__1.C      1    val
# 143867   3IB9      3ib9__1__2.A__2.C__1.C      1    val
# 143868   3IB9      3ib9__2__1.A__1.C__2.C      1    val
# 143869   7WR7      7wr7__1__1.A__1.C__1.C      1    val
#
#                    pocket_key  \
# 0           1grx__1__1.A__1.B
# 1           3grj__1__1.A__1.H
# 2       2grt__1__1.A_2.A__1.C
# 3       2grt__1__1.A_2.A__2.C
# 4           6grq__1__1.A__1.B
# ...                       ...
# 143865      3eja__1__1.A__1.E
# 143866      7kw2__1__1.A__1.C
# 143867      3ib9__1__2.A__2.C
# 143868      3ib9__2__1.A__1.C
# 143869      7wr7__1__1.A__1.C
#
#                                            cleaned_smiles uniprot_id  \
# 0          N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(=O)O)C(=O)O     P68688
# 1                            O=C(O)C1=CNC(C2=CC=CC=C2)=N1     P00811
# 2       N[C@@H](CCC(=O)N[C@@H](CSSC[C@H](NC(=O)CC[C@H]...     P00390
# 3       N[C@@H](CCC(=O)N[C@@H](CSSC[C@H](NC(=O)CC[C@H]...     P00390
# 4       CC(=O)N[C@H]1[C@H](O[C@H]2[C@H](O)[C@@H](NC(C)...     Q8K4V6
# ...                                                   ...        ...
# 143865  CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O     D0VWZ9
# 143866       CC(C)(COP(=O)(O)O)[C@@H](O)C(=O)NCCC(=O)NCCS     Q47NR9
# 143867          O=C(O)CCCC[C@@H]1SC[C@@H]2NC(=O)N[C@@H]21     Q9X4K7
# 143868          O=C(O)CCCC[C@@H]1SC[C@@H]2NC(=O)N[C@@H]21     Q9X4K7
# 143869  CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O     P98073
#
#        Pfam_Families  pfam_id       pfam_name  \
# 0            PF00462  PF00462     Thioredoxin
# 1            PF00144  PF00144  Beta-lactamase
# 2            PF07992  PF07992   NADP_Rossmann
# 3            PF07992  PF07992   NADP_Rossmann
# 4            PF00047  PF00047           E-set
# ...              ...      ...             ...
# 143865       PF03443  PF03443           E-set
# 143866       PF00501  PF00501             ANL
# 143867       PF01039  PF01039  ClpP_crotonase
# 143868       PF01039  PF01039  ClpP_crotonase
# 143869       PF00431  PF00431             CUB
#
#                                             clan_name
# 0                                        Glutaredoxin
# 1                                      Beta-lactamase
# 2       Pyridine nucleotide-disulphide oxidoreductase
# 3       Pyridine nucleotide-disulphide oxidoreductase
# 4                               Immunoglobulin domain
# ...                                               ...
# 143865    Auxiliary Activity family 9 (formerly GH61)
# 143866                             AMP-binding enzyme
# 143867                    Carboxyl transferase domain
# 143868                    Carboxyl transferase domain
# 143869                                     CUB domain
#
# [85164 rows x 11 columns]

# %%
# obtain 50 most common
top_50 = 50
top_50_families = filtered_subset['clan_name'].value_counts().head(top_50)

filtered_subset = filtered_subset[filtered_subset['clan_name'].isin(top_50_families.index)]
filtered_subset
# Out:
#        pdb_id                           ligand_id  Label  split  \
# 8        7GRE              7gre__1__1.A__1.C__1.C      1  train
# 9        7GRX          7grx__1__1.B__1.N_1.O__1.N      1  train
# 20       7GRN              7grn__1__1.B__1.J__1.J      1  train
# 21       7GRT      7grt__1__1.A__1.C_1.E_1.I__1.C      1  train
# 28       7GRY          7gry__1__1.B__1.M_1.N__1.N      1  train
# ...       ...                                 ...    ...    ...
# 143589   7DNZ  7dnz__1__1.A_1.B__1.C_1.H_1.I__1.I      1    val
# 143590   7DNZ              7dnz__1__1.A__1.F__1.F      1    val
# 143591   7DNZ              7dnz__1__1.B__1.L__1.L      1    val
# 143592   3LP1  3lp1__2__1.A_2.A__1.C_1.D_1.E__2.C      1    val
# 143593   7LPX              7lpx__1__1.A__1.E__1.E      1    val
#
#                            pocket_key  \
# 8                   7gre__1__1.A__1.C
# 9               7grx__1__1.B__1.N_1.O
# 20                  7grn__1__1.B__1.J
# 21          7grt__1__1.A__1.C_1.E_1.I
# 28              7gry__1__1.B__1.M_1.N
# ...                               ...
# 143589  7dnz__1__1.A_1.B__1.C_1.H_1.I
# 143590              7dnz__1__1.A__1.F
# 143591              7dnz__1__1.B__1.L
# 143592  3lp1__2__1.A_2.A__1.C_1.D_1.E
# 143593              7lpx__1__1.A__1.E
#
#                                            cleaned_smiles uniprot_id  \
# 8                          FC(F)(F)C1=NNC(C2=CC=NC=C2)=C1     P0DTD1
# 9                            O=C1CCC(=O)N1C1=CC=C(F)C=C1F     P0DTD1
# 20                 FC(F)(F)C1=CC=C2NC([C@H]3CCNC3)=NC2=C1     P0DTD1
# 21                     O=C(NCC1=CC=C2OCCC2=C1)C1=CC=CC=C1     P0DTD1
# 28                       O=C1CCC(=O)N1C1=CC(Cl)=CC(Cl)=C1     P0DTD1
# ...                                                   ...        ...
# 143589     N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(=O)O)C(=O)O     Q9NP58
# 143590  CC(C)CCC[C@@H](C)[C@H]1CC[C@H]2[C@@H]3CC=C4C[C...     Q9NP58
# 143591  CC(C)CCC[C@@H](C)[C@H]1CC[C@H]2[C@@H]3CC=C4C[C...     Q9NP58
# 143592                  O=C1C(C2CCCC2)=C(O)C2=CC=CN=C2N1O     P04585
# 143593  CC1=C(C(=O)N[C@@H](CN)C2=NC=C(CO)S2)NC(C2=CC=C...     P03366
#
#        Pfam_Families  pfam_id      pfam_name  \
# 8            PF13087  PF13087  P-loop_NTPase
# 9            PF13087  PF13087  P-loop_NTPase
# 20           PF13087  PF13087  P-loop_NTPase
# 21           PF13087  PF13087  P-loop_NTPase
# 28           PF13087  PF13087  P-loop_NTPase
# ...              ...      ...            ...
# 143589       PF00664  PF00664   ABC_membrane
# 143590       PF00664  PF00664   ABC_membrane
# 143591       PF00664  PF00664   ABC_membrane
# 143592       PF00540  PF00540         Matrix
# 143593       PF00540  PF00540         Matrix
#
#                                     clan_name
# 8                                  AAA domain
# 9                                  AAA domain
# 20                                 AAA domain
# 21                                 AAA domain
# 28                                 AAA domain
# ...                                       ...
# 143589   ABC transporter transmembrane region
# 143590   ABC transporter transmembrane region
# 143591   ABC transporter transmembrane region
# 143592  gag gene protein p17 (matrix protein)
# 143593  gag gene protein p17 (matrix protein)
#
# [43134 rows x 11 columns]

# %%
# Count frequencies
pfamily_counts = filtered_subset['clan_name'].value_counts() # there are already only top 50 families in the df

# Plot
plt.figure(figsize=(12, 7))
sns.barplot(x=pfamily_counts.index, y=pfamily_counts.values, palette="viridis")
plt.xlabel("Protein Family")
plt.ylabel("Count")
plt.title("Frequency of Protein Families Train+Val splits (no top 5 viruses)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# the top 5 viruses are no longer in the plot, we have the correct subset
# Out:
# /tmp/ipython-input-41-3098503413.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=pfamily_counts.index, y=pfamily_counts.values, palette="viridis")

# %%
# Plot
plt.figure(figsize=(12, 7))
sns.barplot(y=pfamily_counts.index, x=pfamily_counts.values, palette="viridis")
plt.ylabel("Protein Family")
plt.xlabel("Count")
plt.title("Frequency of Protein Families in 'Without Top 5 Virus' set")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig(os.path.join(output_dir, f"novirus_families_freq.png"), dpi=300,  bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipython-input-42-779190836.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=pfamily_counts.index, x=pfamily_counts.values, palette="viridis")

# %%
filtered_subset.to_csv('/content/drive/MyDrive/Binder_Generation/protein_pocket_analysis/In-domain_top50_no_virus_allpdbs.csv')
filtered_subset
# Out:
#        pdb_id                           ligand_id  Label  split  \
# 8        7GRE              7gre__1__1.A__1.C__1.C      1  train
# 9        7GRX          7grx__1__1.B__1.N_1.O__1.N      1  train
# 20       7GRN              7grn__1__1.B__1.J__1.J      1  train
# 21       7GRT      7grt__1__1.A__1.C_1.E_1.I__1.C      1  train
# 28       7GRY          7gry__1__1.B__1.M_1.N__1.N      1  train
# ...       ...                                 ...    ...    ...
# 143589   7DNZ  7dnz__1__1.A_1.B__1.C_1.H_1.I__1.I      1    val
# 143590   7DNZ              7dnz__1__1.A__1.F__1.F      1    val
# 143591   7DNZ              7dnz__1__1.B__1.L__1.L      1    val
# 143592   3LP1  3lp1__2__1.A_2.A__1.C_1.D_1.E__2.C      1    val
# 143593   7LPX              7lpx__1__1.A__1.E__1.E      1    val
#
#                            pocket_key  \
# 8                   7gre__1__1.A__1.C
# 9               7grx__1__1.B__1.N_1.O
# 20                  7grn__1__1.B__1.J
# 21          7grt__1__1.A__1.C_1.E_1.I
# 28              7gry__1__1.B__1.M_1.N
# ...                               ...
# 143589  7dnz__1__1.A_1.B__1.C_1.H_1.I
# 143590              7dnz__1__1.A__1.F
# 143591              7dnz__1__1.B__1.L
# 143592  3lp1__2__1.A_2.A__1.C_1.D_1.E
# 143593              7lpx__1__1.A__1.E
#
#                                            cleaned_smiles uniprot_id  \
# 8                          FC(F)(F)C1=NNC(C2=CC=NC=C2)=C1     P0DTD1
# 9                            O=C1CCC(=O)N1C1=CC=C(F)C=C1F     P0DTD1
# 20                 FC(F)(F)C1=CC=C2NC([C@H]3CCNC3)=NC2=C1     P0DTD1
# 21                     O=C(NCC1=CC=C2OCCC2=C1)C1=CC=CC=C1     P0DTD1
# 28                       O=C1CCC(=O)N1C1=CC(Cl)=CC(Cl)=C1     P0DTD1
# ...                                                   ...        ...
# 143589     N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(=O)O)C(=O)O     Q9NP58
# 143590  CC(C)CCC[C@@H](C)[C@H]1CC[C@H]2[C@@H]3CC=C4C[C...     Q9NP58
# 143591  CC(C)CCC[C@@H](C)[C@H]1CC[C@H]2[C@@H]3CC=C4C[C...     Q9NP58
# 143592                  O=C1C(C2CCCC2)=C(O)C2=CC=CN=C2N1O     P04585
# 143593  CC1=C(C(=O)N[C@@H](CN)C2=NC=C(CO)S2)NC(C2=CC=C...     P03366
#
#        Pfam_Families  pfam_id      pfam_name  \
# 8            PF13087  PF13087  P-loop_NTPase
# 9            PF13087  PF13087  P-loop_NTPase
# 20           PF13087  PF13087  P-loop_NTPase
# 21           PF13087  PF13087  P-loop_NTPase
# 28           PF13087  PF13087  P-loop_NTPase
# ...              ...      ...            ...
# 143589       PF00664  PF00664   ABC_membrane
# 143590       PF00664  PF00664   ABC_membrane
# 143591       PF00664  PF00664   ABC_membrane
# 143592       PF00540  PF00540         Matrix
# 143593       PF00540  PF00540         Matrix
#
#                                     clan_name
# 8                                  AAA domain
# 9                                  AAA domain
# 20                                 AAA domain
# 21                                 AAA domain
# 28                                 AAA domain
# ...                                       ...
# 143589   ABC transporter transmembrane region
# 143590   ABC transporter transmembrane region
# 143591   ABC transporter transmembrane region
# 143592  gag gene protein p17 (matrix protein)
# 143593  gag gene protein p17 (matrix protein)
#
# [43134 rows x 11 columns]

# %%
# Sample randomly 1 proteins per pfamily
balanced_subset = filtered_subset.groupby('clan_name').sample(n=1, random_state=42)

# Now balanced_subset is balanced across pfamilies
balanced_subset.to_csv('/content/drive/MyDrive/Binder_Generation/protein_pocket_analysis/In-domain_top50_novirus.csv')
balanced_subset
# Out:
#        pdb_id                                     ligand_id  Label  split  \
# 94692    1F88                        1f88__3__1.B__1.R__3.R      1  train
# 61275    5K5T                        5k5t__3__4.A__4.J__3.J      1  train
# 6292     5UX4                        5ux4__2__1.B__1.H__2.H      1  train
# 26478    7ZQV                    7zqv__1__1.A_1.B__1.C__1.C      1  train
# 142638   6UJR                        6ujr__1__1.A__1.B__1.B      1    val
# 122957   7VCT                        7vct__1__1.C__1.O__1.O      1  train
# 123128   5EHQ                        5ehq__1__1.A__1.F__1.F      1  train
# 111608   9B03                    9b03__1__1.A__1.I_1.J__1.I      1  train
# 132665   5IKV                        5ikv__1__1.A__1.E__1.E      1  train
# 70894    4BU3                        4bu3__1__1.A__1.F__1.F      1  train
# 88404    2RTN                        2rtn__2__2.A__2.C__2.C      1  train
# 40878    6RMK                        6rmk__1__1.A__1.B__1.B      1  train
# 79695    5N49                        5n49__1__1.B__1.C__1.C      1  train
# 103146   4O7B                        4o7b__1__1.A__1.B__1.B      1  train
# 121199   7RGL                7rgl__1__1.B_1.C__1.M_1.N__1.M      1  train
# 29022    1RB8  1rb8__1__21.A_25.A_25.C__25.D_25.E_25.H__1.E      1  train
# 22708    6EUC                        6euc__1__2.A__2.C__1.C      1  train
# 91286    7T4V                        7t4v__2__1.B__1.E__2.E      1  train
# 58990    4WNV                4wnv__2__1.B__1.M_1.N_1.O__2.M      1  train
# 43299    8PWN        8pwn__1__1.A__1.G_1.H_1.K_1.N_1.O__1.O      1  train
# 14599    2KGK                        2kgk__1__1.A__1.C__1.C      1  train
# 94656    3F8S                        3f8s__3__1.B__1.K__3.K      1  train
# 115548   4P8Q                        4p8q__1__1.B__1.G__1.G      1  train
# 75058    7LIT               7lit__1__3.A_4.A_42.A__4.B__1.B      1  train
# 97343    6F6N                        6f6n__1__1.A__1.F__1.F      1  train
# 121943   1IBQ                        1ibq__2__1.B__1.I__2.I      1  train
# 114946   8CO3                    8co3__1__1.C__1.I_1.J__1.J      1  train
# 1360     8F1Y                        8f1y__1__1.A__1.B__1.B      1  train
# 47381    5SIZ                        5siz__2__1.B__1.J__2.J      1  train
# 108316   2B15                    2b15__1__1.B_2.B__1.F__1.F      1  train
# 79134    4N61                        4n61__1__3.B__3.H__1.H      1  train
# 65491    6WFS                 6wfs__1__16.A_20.A__16.E__1.E      1  train
# 95658    4NM8                        4nm8__1__1.E__1.R__1.R      1  train
# 69549    8G1A                        8g1a__1__1.A__1.D__1.D      1  train
# 96699    8SRB            8srb__1__1.C_1.D__1.O_1.P_1.T__1.P      1  train
# 71799    5F5Q                        5f5q__1__1.B__1.H__1.H      1  train
# 64652    5Z8Y                        5z8y__1__1.A__1.N__1.N      1  train
# 59450    3IPS                        3ips__1__1.A__1.F__1.F      1  train
# 7555     2QWK                        2qwk__1__4.A__4.D__1.D      1  train
# 18713    5AFM                    5afm__1__1.A_1.B__1.J__1.J      1  train
# 118079   2JBK                        2jbk__1__2.A__2.B__1.B      1  train
# 127225   5EGC                        5egc__6__9.A__9.B__6.B      1  train
# 32297    8AYX                 8ayx__1__19.A_25.A__25.E__1.E      1  train
# 112506   1NY3                        1ny3__2__8.A__8.B__2.B      1  train
# 59861    2DQ7                        2dq7__1__1.A__1.B__1.B      1  train
# 86346    6F76                        6f76__1__1.B__1.L__1.L      1  train
# 19083    3QLT                        3qlt__1__1.A__1.C__1.C      1  train
# 132939   1Q3S                    1q3s__1__1.D__1.O_1.P__1.P      1  train
# 104576   6KPP                    6kpp__1__1.A_1.B__1.J__1.J      1  train
# 45709    8QUX                8qux__1__1.A_5.A__1.C_1.D__1.C      1  train
#
#                                      pocket_key  \
# 94692                         1f88__3__1.B__1.R
# 61275                         5k5t__3__4.A__4.J
# 6292                          5ux4__2__1.B__1.H
# 26478                     7zqv__1__1.A_1.B__1.C
# 142638                        6ujr__1__1.A__1.B
# 122957                        7vct__1__1.C__1.O
# 123128                        5ehq__1__1.A__1.F
# 111608                    9b03__1__1.A__1.I_1.J
# 132665                        5ikv__1__1.A__1.E
# 70894                         4bu3__1__1.A__1.F
# 88404                         2rtn__2__2.A__2.C
# 40878                         6rmk__1__1.A__1.B
# 79695                         5n49__1__1.B__1.C
# 103146                        4o7b__1__1.A__1.B
# 121199                7rgl__1__1.B_1.C__1.M_1.N
# 29022   1rb8__1__21.A_25.A_25.C__25.D_25.E_25.H
# 22708                         6euc__1__2.A__2.C
# 91286                         7t4v__2__1.B__1.E
# 58990                 4wnv__2__1.B__1.M_1.N_1.O
# 43299         8pwn__1__1.A__1.G_1.H_1.K_1.N_1.O
# 14599                         2kgk__1__1.A__1.C
# 94656                         3f8s__3__1.B__1.K
# 115548                        4p8q__1__1.B__1.G
# 75058                7lit__1__3.A_4.A_42.A__4.B
# 97343                         6f6n__1__1.A__1.F
# 121943                        1ibq__2__1.B__1.I
# 114946                    8co3__1__1.C__1.I_1.J
# 1360                          8f1y__1__1.A__1.B
# 47381                         5siz__2__1.B__1.J
# 108316                    2b15__1__1.B_2.B__1.F
# 79134                         4n61__1__3.B__3.H
# 65491                  6wfs__1__16.A_20.A__16.E
# 95658                         4nm8__1__1.E__1.R
# 69549                         8g1a__1__1.A__1.D
# 96699             8srb__1__1.C_1.D__1.O_1.P_1.T
# 71799                         5f5q__1__1.B__1.H
# 64652                         5z8y__1__1.A__1.N
# 59450                         3ips__1__1.A__1.F
# 7555                          2qwk__1__4.A__4.D
# 18713                     5afm__1__1.A_1.B__1.J
# 118079                        2jbk__1__2.A__2.B
# 127225                        5egc__6__9.A__9.B
# 32297                  8ayx__1__19.A_25.A__25.E
# 112506                        1ny3__2__8.A__8.B
# 59861                         2dq7__1__1.A__1.B
# 86346                         6f76__1__1.B__1.L
# 19083                         3qlt__1__1.A__1.C
# 132939                    1q3s__1__1.D__1.O_1.P
# 104576                    6kpp__1__1.A_1.B__1.J
# 45709                 8qux__1__1.A_5.A__1.C_1.D
#
#                                            cleaned_smiles uniprot_id  \
# 94692               CC(C=CC=C(C)C=CC1=C(C)CCCC1(C)C)=CC=O     P02699
# 61275   CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O     P41180
# 6292    NC1=N[C@@]2(CO1)C1=CC(C3=CC=CN=C3F)=CC=C1OC1=C...     P24268
# 26478   C#CC[C@@H](C(=O)N[C@H](CCC(=O)OCC)C[C@@H]1CCNC...     P0DTD1
# 142638          BrC1=CC=C(OC2=C(Br)C=C(Br)C=C2Br)C(Br)=C1     P21447
# 122957  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@](=O)(O)O...     P55072
# 123128  NC1=CC=C2C(=C1)C(C1=CC=CC=C1)=[N+](CCCCCC1=CN(...     P21836
# 111608  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@](=O)(O)O...     P68135
# 132665            O=C(O)C1=CC=CC=C1NC1=CC=CC(C(F)(F)F)=C1     P35354
# 70894                   O=C1NC(C2=CC=CC=C2)=NC2=CC=CC=C12     Q9H2K2
# 88404              N=C1N[C@H]2[C@H](CS[C@H]2CCCCC(=O)O)N1     P22629
# 40878               CC(C=CC=C(C)C=CC1=C(C)CCCC1(C)C)=CC=O     P02945
# 79695   CC1=CC2=C(C=C1N1C(=O)C3=CC=CC4=CC=CC(=C34)C1=O...     O95696
# 103146  CC1=CC=CC(OC2=NC=CC(C3=C(C4=CC=C(F)C=C4)N=CN3C...     O60885
# 121199  O=C1NC=NC2=C1N=CN2[C@@H]1O[C@H](COP(=O)(O)O)[C...     P20839
# 29022   NC1=NC(=O)N([C@H]2C[C@H](O)[C@@H](COP(=O)(O)O)...     P08767
# 22708   CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O     P04058
# 91286   CC1=CC(C(=O)O)=CC=C1CN1CCC[C@H](O[C@H](CO)C2=C...     Q13976
# 58990   C=C[C@H]1C[N@@]2CC[C@H]1C[C@H]2[C@H](O)C1=CC=N...     P10635
# 43299   CC(C)CCC[C@@H](C)[C@H]1CC[C@H]2[C@@H]3CC=C4C[C...     P0ABE7
# 14599            CCC1=NC(N)=NC(N)=C1C#CCC1=CC(OC)=CC=C1OC     Q81R22
# 94656   O=C([C@@H]1C[C@H](N2CCN(C3=NC=CC=N3)CC2)CN1)N1...     P27487
# 115548  CC(=O)N[C@H]1[C@H](O[C@H]2[C@H](O)[C@@H](NC(C)...     Q9UIQ6
# 75058   CC1=CC2=C(C=C1C)N(C[C@H](O)[C@H](O)[C@H](O)CO)...     Q9WZP2
# 97343   CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O     Q05320
# 121943        OC[C@H]1O[C@H](O)[C@@H](O)[C@@H](O)[C@@H]1O     Q12567
# 114946  CC1=CC(C2=CC=C(S(N)(=O)=O)S2)=CN=C1C1=CC=CC2=N...     O43570
# 1360    CCC(=O)N1CCC(OC2=CC3=C(NC4=CC=C(Cl)C(Cl)=C4F)N...     P00533
# 47381   COC1=NC=C(C2CC2)N=C1C(=O)NCCC1=NC(C2=CC=CN=C2)...     Q9Y233
# 108316           O=[N+]([O-])C1=CC=C(O)C([N+](=O)[O-])=C1     P02766
# 79134   CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O     R4NN21
# 65491   NS(=O)(=O)C1=CC=C(CCNC(=O)C2=CC=C3SC4=CC=CC=C4...     P03147
# 95658   CC(=O)N[C@H]1[C@H](O[C@H]2[C@H](O)[C@@H](NC(C)...     P01834
# 69549   CC(=O)N[C@H]1[C@H](O[C@H]2[C@H](O)[C@@H](NC(C)...     O60939
# 96699   CC(C)CCC[C@@H](C)[C@H]1CC[C@H]2[C@@H]3CC=C4C[C...     F2UB89
# 71799         CO[C@H]1O[C@H](CO)[C@@H](O)[C@H](O)[C@@H]1O     C0HJY1
# 64652   CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O     O43300
# 59450   CCCC1=C(OCCCSC2=CC=C(CC(=O)O)C=C2Cl)C=CC2=C1ON...     Q13133
# 7555    CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O     P03472
# 18713                         O=C(NCCCO)C1=CC(Br)=C(Br)N1     P36544
# 118079  CC(=O)N[C@H]1[C@H](O[C@H]2[C@H](O)[C@@H](NC(C)...     Q04609
# 127225  CC(=O)N[C@H]1[C@H]([C@H](O)[C@H](O)CO)O[C@@](O...     Q9WBP8
# 32297      N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(=O)O)C(=O)O     Q84895
# 112506  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@](=O)(O)O...     P49137
# 59861   CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)N1C3=CC=CC...     P06241
# 86346   COC1=CC(C2=CC=CC3=C2OCCO3)=CC=C1NC1=CC=CC(CN(C...     P01116
# 19083   CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O     P42260
# 132939  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@](=O)(O)O...     P61112
# 104576  COC1=CC(C(=O)C2=C(C)OC3=C(O)C(OC)=CC=C23)=CC(O...     P02554
# 45709                   O=C1CN(CC2=CC=CC=C2)C2=CC=CC=C2N1     P12493
#
#        Pfam_Families  pfam_id        pfam_name  \
# 94692        PF00001  PF00001           GPCR_A
# 61275        PF00003  PF00003           GPCR_A
# 6292         PF07966  PF07966              NaN
# 26478        PF13087  PF13087    P-loop_NTPase
# 142638       PF00664  PF00664     ABC_membrane
# 122957       PF00004  PF00004    P-loop_NTPase
# 123128       PF08674  PF08674              NaN
# 111608       PF00022  PF00022     Actin_ATPase
# 132665       PF03098  PF03098       Peroxidase
# 70894        PF00023  PF00023              Ank
# 88404        PF01382  PF01382              NaN
# 40878        PF01036  PF01036           GPCR_A
# 79695        PF00439  PF00439              NaN
# 103146       PF17035  PF17035              BET
# 121199       PF00571  PF00571              NaN
# 29022        PF02305  PF02305      ssDNA_NP_VP
# 22708        PF00135  PF00135     AB_hydrolase
# 91286        PF00027  PF00027            Cupin
# 58990        PF00067  PF00067              NaN
# 43299        PF07361  PF07361              NaN
# 14599        PF00186  PF00186           DHFred
# 94656        PF00930  PF00930   Beta_propeller
# 115548       PF11838  PF11838            E-set
# 75058        PF04454  PF04454       Phage-coat
# 97343        PF22307  PF22307              NaN
# 121943       PF00026  PF00026     Peptidase_AA
# 114946       PF00194  PF00194              NaN
# 1360         PF00757  PF00757  GF_recep_C-rich
# 47381        PF01590  PF01590              GAF
# 108316       PF00576  PF00576    Transthyretin
# 79134        PF00509  PF00509              NaN
# 65491        PF00906  PF00906              NaN
# 95658        PF07654  PF07654            E-set
# 69549        PF07686  PF07686            E-set
# 96699        PF00520  PF00520      Ion_channel
# 71799        PF00139  PF00139     Concanavalin
# 64652        PF13855  PF13855              LRR
# 59450        PF00104  PF00104              NaN
# 7555         PF00064  PF00064   Beta_propeller
# 18713        PF02931  PF02931              NaN
# 118079       PF02225  PF02225         Leu-IlvD
# 127225       PF00740  PF00740      ssDNA_NP_VP
# 32297        PF02226  PF02226    Nucleoplasmin
# 112506       PF00069  PF00069          PKinase
# 59861        PF07714  PF07714          PKinase
# 86346        PF00071  PF00071    P-loop_NTPase
# 19083        PF01094  PF01094      Periplas_BP
# 132939       PF00118  PF00118              NaN
# 104576       PF00091  PF00091    NADP_Rossmann
# 45709        PF00540  PF00540           Matrix
#
#                                                 clan_name
# 94692         7 transmembrane receptor (rhodopsin family)
# 61275      7 transmembrane sweet-taste receptor of 3 GCPR
# 6292                                       A1 Propeptide
# 26478                                          AAA domain
# 142638               ABC transporter transmembrane region
# 122957  ATPase family associated with various cellular...
# 123128        Acetylcholinesterase tetramerisation domain
# 111608                                              Actin
# 132665                             Animal haem peroxidase
# 70894                                      Ankyrin repeat
# 88404                                       Avidin family
# 40878                      Bacteriorhodopsin-like protein
# 79695                                         Bromodomain
# 103146  Bromodomain extra-terminal - transcription reg...
# 121199                                         CBS domain
# 29022                          Capsid protein (F protein)
# 22708                             Carboxylesterase family
# 91286                    Cyclic nucleotide-binding domain
# 58990                                     Cytochrome P450
# 43299                                     Cytochrome b562
# 14599                             Dihydrofolate reductase
# 94656   Dipeptidyl peptidase IV (DPP IV) N-terminal re...
# 115548                       ERAP1-like C-terminal domain
# 75058                Encapsulating protein for peroxidase
# 97343             Envelope glycoprotein GP2-like, HR1-HR2
# 121943                       Eukaryotic aspartyl protease
# 114946                 Eukaryotic-type carbonic anhydrase
# 1360                      Furin-like cysteine rich region
# 47381                                          GAF domain
# 108316                        HIUase/Transthyretin family
# 79134                                      Haemagglutinin
# 65491                              Hepatitis core antigen
# 95658                        Immunoglobulin C1-set domain
# 69549                         Immunoglobulin V-set domain
# 96699                               Ion transport protein
# 71799                                Legume lectin domain
# 64652                                 Leucine rich repeat
# 59450   Ligand-binding domain of nuclear hormone receptor
# 7555                                        Neuraminidase
# 18713   Neurotransmitter-gated ion-channel ligand bind...
# 118079                                          PA domain
# 127225                        Parvovirus coat protein VP2
# 32297                     Picornavirus coat protein (VP4)
# 112506                              Protein kinase domain
# 59861        Protein tyrosine and serine/threonine kinase
# 86346                                          Ras family
# 19083               Receptor family ligand binding region
# 132939                      TCP-1/cpn60 chaperonin family
# 104576                 Tubulin/FtsZ family, GTPase domain
# 45709               gag gene protein p17 (matrix protein)

# %%
# Filter only train + val or whatever split you want
filtered_df = metadata_pfam[metadata_pfam['split'].isin(['train', 'val'])]

# Find the minimum number of samples per pfamily
min_count = filtered_df['Pfam_Families'].value_counts().min()

# Sample min_count proteins per pfamily
balanced_subset = filtered_df.groupby('Pfam_Families').sample(n=min_count, random_state=42)

# Now balanced_subset is balanced across pfamilies
balanced_subset
# Out:
#        pdb_id                               ligand_id  Label  split  \
# 94692    1F88                  1f88__3__1.B__1.R__3.R      1  train
# 32773    7EVM              7evm__1__1.E__1.G_1.K__1.G      1  train
# 95151    8WPG                  8wpg__1__1.B__1.F__1.F      1  train
# 97647    8FCP                  8fcp__1__1.A__1.J__1.J      1  train
# 93349    8Y3X              8y3x__1__1.A_1.B__1.F__1.F      1  train
# ...       ...                                     ...    ...    ...
# 115673   8IY2  8iy2__2__2.B_6.B__2.T_2.U_6.T_6.U__2.U      1  train
# 77490    4N14                  4n14__1__1.A__1.B__1.B      1  train
# 102174   5MDM                  5mdm__1__1.B__1.E__1.E      1  train
# 35957    6TMR                  6tmr__1__1.A__1.B__1.B      1  train
# 122126   4F2D          4f2d__2__1.A_1.C__1.I_1.J__2.J      1  train
#
#                                pocket_key  \
# 94692                   1f88__3__1.B__1.R
# 32773               7evm__1__1.E__1.G_1.K
# 95151                   8wpg__1__1.B__1.F
# 97647                   8fcp__1__1.A__1.J
# 93349               8y3x__1__1.A_1.B__1.F
# ...                                   ...
# 115673  8iy2__2__2.B_6.B__2.T_2.U_6.T_6.U
# 77490                   4n14__1__1.A__1.B
# 102174                  5mdm__1__1.B__1.E
# 35957                   6tmr__1__1.A__1.B
# 122126          4f2d__2__1.A_1.C__1.I_1.J
#
#                                            cleaned_smiles uniprot_id  \
# 94692               CC(C=CC=C(C)C=CC1=C(C)CCCC1(C)C)=CC=O     P02699
# 32773   CC(C)CCC[C@@H](C)[C@H]1CC[C@H]2[C@@H]3CC=C4C[C...     P43220
# 95151   CC(=O)N[C@H]1[C@H](O[C@H]2[C@H](O)[C@@H](NC(C)...     P41180
# 97647   NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@](=O)(O)O...     P55072
# 93349   NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@@](=O)(O)...     P0A9R7
# ...                                                   ...        ...
# 115673  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO)[C@@H](OP(=...     Q6PVL0
# 77490   CC1=NC=C([N+](=O)[O-])N1CCOC(=O)N[C@@H](NC1=NC...     Q12834
# 102174  CC(=O)N[C@H]1[C@H](O[C@H]2[C@H](O)[C@@H](NC(C)...     P13180
# 35957   CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O     P0C572
# 122126                         OC[C@@H](O)C(O)[C@@H](O)CO     P08202
#
#        Pfam_Families  pfam_id       pfam_name  \
# 94692        PF00001  PF00001          GPCR_A
# 32773        PF00002  PF00002          GPCR_A
# 95151        PF00003  PF00003          GPCR_A
# 97647        PF00004  PF00004   P-loop_NTPase
# 93349        PF00005  PF00005   P-loop_NTPase
# ...              ...      ...             ...
# 115673       PF24729  PF24729             NaN
# 77490        PF24807  PF24807  Beta_propeller
# 102174       PF24833  PF24833             NaN
# 35957        PF24834  PF24834              PH
# 122126       PF24856  PF24856     AraA_N-like
#
#                                                 clan_name
# 94692         7 transmembrane receptor (rhodopsin family)
# 32773          7 transmembrane receptor (Secretin family)
# 95151      7 transmembrane sweet-taste receptor of 3 GCPR
# 97647   ATPase family associated with various cellular...
# 93349                                     ABC transporter
# ...                                                   ...
# 115673                          Acb2/Tad1, hairpin domain
# 77490                             CDC20/Fizzy WD40 domain
# 102174    Rhabdovirus spike glycoprotein G central domain
# 35957                Rhabdovirus glycoprotein G PH domain
# 122126               L-arabinose isomerase central domain
#
# [1685 rows x 11 columns]

# %%
# Filter only train + val or whatever split you want
filtered_df = metadata_pfam[metadata_pfam['split'].isin(['test'])]

# Find the minimum number of samples per pfamily
min_count = filtered_df['Pfam_Families'].value_counts().min()

# Sample min_count proteins per pfamily
balanced_subset = filtered_df.groupby('Pfam_Families').sample(n=min_count, random_state=42)

# Now balanced_subset is balanced across pfamilies
balanced_subset
# Out:
#        pdb_id                         ligand_id  Label split  \
# 148204   4BSU            4bsu__2__1.A__1.I__2.I      1  test
# 148170   7R86        7r86__1__1.A_1.C__1.W__1.W      1  test
# 147902   4MS1            4ms1__1__1.A__1.F__1.F      1  test
# 146501   4P0A            4p0a__1__1.A__1.B__1.B      1  test
# 147829   3QCW            3qcw__1__1.A__1.C__1.C      1  test
# ...       ...                               ...    ...   ...
# 148001   3K6S            3k6s__3__1.E__1.Q__3.Q      1  test
# 144715   6FB3            6fb3__3__1.C__1.R__3.R      1  test
# 147302   6KPM            6kpm__1__1.A__1.B__1.B      1  test
# 145011   8K7P  8k7p__1__1.B__1.BA_1.U_1.Y__1.BA      1  test
# 146583   4TNU        4tnu__1__1.A__1.C_1.D__1.D      1  test
#
#                         pocket_key  \
# 148204           4bsu__2__1.A__1.I
# 148170       7r86__1__1.A_1.C__1.W
# 147902           4ms1__1__1.A__1.F
# 146501           4p0a__1__1.A__1.B
# 147829           3qcw__1__1.A__1.C
# ...                            ...
# 148001           3k6s__3__1.E__1.Q
# 144715           6fb3__3__1.C__1.R
# 147302           6kpm__1__1.A__1.B
# 145011  8k7p__1__1.B__1.BA_1.U_1.Y
# 146583       4tnu__1__1.A__1.C_1.D
#
#                                            cleaned_smiles  uniprot_id  \
# 148204  CC(=O)N[C@H]1[C@H](O[C@H]2[C@H](O)[C@@H](NC(C)...      O75473
# 148170        OC[C@H]1O[C@H](O)[C@@H](O)[C@@H](O)[C@@H]1O      Q3UHD1
# 147902  CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O      O75899
# 146501  CC(C)C[C@H](NC(=O)[C@@H](N)CC(=O)O)C(=O)N[C@@H...      P55072
# 147829  CC(=O)N[C@H]1[C@H](O[C@H]2[C@H](O)[C@@H](NC(C)...      Q28146
# ...                                                   ...         ...
# 148001  CC(=O)N[C@H]1[C@H](O[C@H]2[C@H](O)[C@@H](NC(C)...      P05107
# 144715  CC(=O)N[C@H]1[C@H](O[C@H]2[C@H](O)[C@@H](NC(C)...      Q9DER5
# 147302        C[C@@H]1O[C@@H](O)[C@@H](O)[C@H](O)[C@@H]1O      G3JPF7
# 145011                           CCCCCCCCCCCC=CCCCCC(=O)O  A0A0U1MWF9
# 146583                C[P@@](=O)(O)N[C@@H](CC(=O)O)C(=O)O      P45381
#
#        Pfam_Families
# 148204       PF00001
# 148170       PF00002
# 147902       PF00003
# 146501       PF00004
# 147829       PF00008
# ...              ...
# 148001       PF23105
# 144715       PF23106
# 147302       PF23916
# 145011       PF24708
# 146583       PF24827
#
# [733 rows x 8 columns]

# %% [markdown]
# # Creating out-domain subsets

# %%
test_set = metadata_pfam[metadata_pfam['split'] == 'test']
test_set
# Out:
#        pdb_id                       ligand_id  Label split  \
# 143870   5GR1          5gr1__1__1.A__1.B__1.B      1  test
# 143871   5GRK          5grk__1__1.A__1.E__1.E      1  test
# 143872   5GRK          5grk__2__1.C__1.G__2.G      1  test
# 143873   5GRK          5grk__2__1.D__1.H__2.H      1  test
# 143874   5CJV  5cjv__1__1.A__1.F_1.G_1.H__1.F      1  test
# ...       ...                             ...    ...   ...
# 148306   5IB9  5ib9__1__1.A__1.B_1.C_1.H__1.H      1  test
# 148307   5IB9  5ib9__1__2.A__2.B_2.C_2.H__1.H      1  test
# 148308   4XPP          4xpp__1__2.A__2.B__1.B      1  test
# 148309   3UG6  3ug6__1__1.C_1.D__1.M_1.N__1.M      1  test
# 148310   2Y8L          2y8l__1__1.C__1.E__1.E      1  test
#
#                        pocket_key  \
# 143870          5gr1__1__1.A__1.B
# 143871          5grk__1__1.A__1.E
# 143872          5grk__2__1.C__1.G
# 143873          5grk__2__1.D__1.H
# 143874  5cjv__1__1.A__1.F_1.G_1.H
# ...                           ...
# 148306  5ib9__1__1.A__1.B_1.C_1.H
# 148307  5ib9__1__2.A__2.B_2.C_2.H
# 148308          4xpp__1__2.A__2.B
# 148309  3ug6__1__1.C_1.D__1.M_1.N
# 148310          2y8l__1__1.C__1.E
#
#                                            cleaned_smiles  uniprot_id  \
# 143870  OC[C@H]1O[C@H](O[C@H]2[C@H](O)[C@@H](O)[C@@H](...      B1WPM8
# 143871                            O=C1NC(=O)C2=C(NC=N2)N1         NaN
# 143872                            O=C1NC(=O)C2=C(NC=N2)N1         NaN
# 143873                            O=C1NC(=O)C2=C(NC=N2)N1         NaN
# 143874  NC1=NC2=C(N=CN2[C@@H]2O[C@H](CO[P@](=O)(O)OP(=...      Q1LRY0
# ...                                                   ...         ...
# 148306  CC(C)C[C@H](NC(=O)[C@@H](O)[C@H](N)CC1=CC=CC=C...      A2V759
# 148307  CC(C)C[C@H](NC(=O)[C@@H](O)[C@H](N)CC1=CC=CC=C...      A2V759
# 148308         OC[C@H]1O[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O  A0A0F7R6D6
# 148309  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@](=O)(O)O...      Q58542
# 148310  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](CO[P@](=O)(O)O...      O43741
#
#        Pfam_Families  pfam_id      pfam_name  \
# 143870       PF00128  PF00128     TIM_barrel
# 143871           NaN      NaN            NaN
# 143872           NaN      NaN            NaN
# 143873           NaN      NaN            NaN
# 143874       PF02310  PF02310            NaN
# ...              ...      ...            ...
# 148306       PF02225  PF02225       Leu-IlvD
# 148307       PF02225  PF02225       Leu-IlvD
# 148308       PF17137  PF17137            NaN
# 148309       PF02374  PF02374  P-loop_NTPase
# 148310       PF16561  PF16561            GHD
#
#                                                 clan_name
# 143870                    Alpha amylase, catalytic domain
# 143871                                                NaN
# 143872                                                NaN
# 143873                                                NaN
# 143874                                 B12 binding domain
# ...                                                   ...
# 148306                                          PA domain
# 148307                                          PA domain
# 148308               Domain of unknown function (DUF5110)
# 148309                          Anion-transporting ATPase
# 148310  Glycogen recognition site of AMP-activated pro...
#
# [4369 rows x 11 columns]

# %%
# obtain 50 most common
top_50 = 52
top_50_families = test_set['clan_name'].value_counts().head(top_50)

filtered_subset_test = test_set[test_set['clan_name'].isin(top_50_families.index)]
filtered_subset_test
# Out:
#        pdb_id                   ligand_id  Label split             pocket_key  \
# 143887   5J3L      5j3l__1__1.A__1.B__1.B      1  test      5j3l__1__1.A__1.B
# 143888   5J3L      5j3l__1__2.A__2.B__1.B      1  test      5j3l__1__2.A__2.B
# 143956   6GO2  6go2__1__1.A__1.B_1.H__1.H      1  test  6go2__1__1.A__1.B_1.H
# 143980   4EOX  4eox__1__1.A__1.B_1.C__1.C      1  test  4eox__1__1.A__1.B_1.C
# 143989   8ETF      8etf__1__1.A__1.I__1.I      1  test      8etf__1__1.A__1.I
# ...       ...                         ...    ...   ...                    ...
# 148286   5JIF      5jif__1__1.B__1.J__1.J      1  test      5jif__1__1.B__1.J
# 148287   5JIF      5jif__1__1.A__1.P__1.P      1  test      5jif__1__1.A__1.P
# 148288   5JIF      5jif__1__1.B__1.U__1.U      1  test      5jif__1__1.B__1.U
# 148289   5GVY      5gvy__1__1.A__1.C__1.C      1  test      5gvy__1__1.A__1.C
# 148290   5GVY      5gvy__1__1.B__1.D__1.D      1  test      5gvy__1__1.B__1.D
#
#                                            cleaned_smiles  uniprot_id  \
# 143887                          O=S(=O)(CCC1CCCC1)N1CCCC1      P9WMC1
# 143888                          O=S(=O)(CCC1CCCC1)N1CCCC1      P9WMC1
# 143956                     CC(C)C[C@H](NS(N)(=O)=O)C(=O)O      P29068
# 143980  O=CN(O)C[C@@H](CC1CCCC1)C(=O)N1CCC[C@H]1C(=O)N...      Q8DP79
# 143989  C[C@H](CCC(=O)CF)[C@H]1CC[C@H]2[C@@H]3CC[C@@H]...  A0A833FHE1
# ...                                                   ...         ...
# 148286  CC(=O)N[C@H]1[C@H](O[C@H]2[C@H](O)[C@@H](NC(C)...      O92367
# 148287  CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O      O92367
# 148288  CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]1O      O92367
# 148289        OC[C@H]1O[C@H](O)[C@@H](O)[C@@H](O)[C@@H]1O      A2WPN7
# 148290        OC[C@H]1O[C@H](O)[C@@H](O)[C@@H](O)[C@@H]1O      A2WPN7
#
#        Pfam_Families  pfam_id       pfam_name  \
# 143887       PF21313  PF21313          TetR_C
# 143888       PF21313  PF21313          TetR_C
# 143956       PF00246  PF00246    ZnExoPePases
# 143980       PF01327  PF01327             NaN
# 143989       PF02275  PF02275             NTN
# ...              ...      ...             ...
# 148286       PF03996  PF03996  SGNH_hydrolase
# 148287       PF03996  PF03996  SGNH_hydrolase
# 148288       PF03996  PF03996  SGNH_hydrolase
# 148289       PF01419  PF01419      Man_lectin
# 148290       PF01419  PF01419      Man_lectin
#
#                                                 clan_name
# 143887  Transcriptional regulator EthR, C-terminal domain
# 143888  Transcriptional regulator EthR, C-terminal domain
# 143956                              Zinc carboxypeptidase
# 143980                            Polypeptide deformylase
# 143989  Linear amide C-N hydrolases, choloylglycine hy...
# ...                                                   ...
# 148286                             Hemagglutinin esterase
# 148287                             Hemagglutinin esterase
# 148288                             Hemagglutinin esterase
# 148289                         Jacalin-like lectin domain
# 148290                         Jacalin-like lectin domain
#
# [1220 rows x 11 columns]

# %%
pfamily_counts = filtered_subset_test['clan_name'].value_counts() # there are already only top 50 families in the df

# Plot
plt.figure(figsize=(12, 7))
sns.barplot(x=pfamily_counts.index, y=pfamily_counts.values, palette="viridis")
plt.xlabel("Protein Family")
plt.ylabel("Count")
plt.title("Frequency of Protein Families in Test Split (out-domain)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# I have been able to replicate the plot so, filtered_subset has the correct top 50 families.
# Out:
# /tmp/ipython-input-46-2077936872.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=pfamily_counts.index, y=pfamily_counts.values, palette="viridis")

# %%
filtered_subset_test.to_csv('/content/drive/MyDrive/Binder_Generation/protein_pocket_analysis/Out-domain_top52_allpdbs.csv')
